# %% [markdown]
# !['no_photo :-('](photo.png "Title")
#
# > ##  A Simple Text-mining Tutorial
# ***

# %% [markdown]
# ### Sections
# [Packages](#Import-packages-and-set-path-to-your-local-directory) <br>
# [Dataset](#Import-dataset-and-perform-basic-operations) <br>
# [Simple bar chart](#Bar-chart) <br>
# [Time series](#Experiment-with-more-months) <br>
# [Frequency analysis](#Part-II)

# %% [markdown]
# ## Packgages to install before the hackathon
#
# #### conda install pandas
# #### conda install numpy
# #### conda install jupyter
# #### conda install -c anaconda nltk
# #### conda install -c plotly plotly
# #### conda install -c menpo pathlib
# #### conda install -c anaconda ipython

# %% [markdown]
# ## Import packages and set path to your local directory

# %%
import numpy as np # scientific computing with Python
import pandas as pd # dealing with dataframes
import nltk # Natural Language Toolkit
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from collections import Counter # self-explanatory
from ast import literal_eval # safely evaluate an expression node or a Unicode or Latin-1 encoded string containing a Python literal or container display
import plotly.plotly as py # package for interactive visualization
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs
import cufflinks as cf
import glob # manages pathnames
from pathlib import Path # also manages pathnames   
from IPython.display import display
nltk.download('stopwords')
init_notebook_mode(connected=True)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kgyodi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ## Import dataset and perform basic operations
# ### In the first example let's import articles from Arstechnica, a well known website covering news and opinions in technology. We limit our analysis to articles published in the ancient times of January 2016.

# %%
# please insert your own path
#path='/Volumes/GoogleDrive/My Drive/NGI/Engineroom/analysis/180814_all_tars/engineroom_news/mod_08/'
path='../mod_0909/'

# %%
# You can change the filename for another article

df=pd.read_csv(path+'dfs_articles2016-01arstechnica.csv', index_col=0)

# %%
# columns of our data frame (df)
df.columns
# Out:
# Index(['text', 'author', 'site', 'link', 'text_token', 'text_token_lower',
#        'text_token_stemmed', 'text_token_count'],
#       dtype='object')

# %%
# check the length of our df
len(df)
# Out:
# 480

# %% [markdown]
# ### Each entry in the df refers to an another article. Besides the self-explanatory metadata e.g. 'author' column you can find some preprocessed data. We have already tokenized articles' text for you and performed stemming on it. You can find the result in the 'text_token_stemmed' column. Moreover, we have checked frequency of all tokens, see: 'text_token_count'.

# %%
# print first five entries, to check last five just use 'tail'
df.head()
# Out:
#                                                     text              author  \
# 5944   \n\n\n\nWithin the past year, Congress voted t...       CYRUS FARIVAR
# 10926  Clean water is essential, yet in certain parts...      SHALINI SAXENA
# 10925  Carpenter ants live in a caste system, where s...      ANNALEE NEWITZ
# 11929  \n\n\n\nOK, we'll admit it—there was a lot of ...  JONATHAN M. GITLIN
# 2875   The coming of the new year gives us an opportu...      SEAN GALLAGHER
#
#               site                                               link  \
# 5944   arstechnica  https://arstechnica.com/tech-policy/2016/01/in...
# 10926  arstechnica  https://arstechnica.com/science/2016/01/reusab...
# 10925  arstechnica  https://arstechnica.com/science/2016/01/slight...
# 11929  arstechnica  https://arstechnica.com/cars/2016/01/ars-drive...
# 2875   arstechnica  https://arstechnica.com/information-technology...
#
#                                               text_token  \
# 5944   ['Within', 'the', 'past', 'year', 'Congress', ...
# 10926  ['Clean', 'water', 'is', 'essential', 'yet', '...
# 10925  ['Carpenter', 'ants', 'live', 'in', 'a', 'cast...
# 11929  ['OK', 'well', 'admit', 'itthere', 'was', 'a',...
# 2875   ['The', 'coming', 'of', 'the', 'new', 'year', ...
#
#                                         text_token_lower  \
# 5944   ['within', 'the', 'past', 'year', 'congress', ...
# 10926  ['clean', 'water', 'is', 'essential', 'yet', '...
# 10925  ['carpenter', 'ants', 'live', 'in', 'a', 'cast...
# 11929  ['ok', 'well', 'admit', 'itthere', 'was', 'a',...
# 2875   ['the', 'coming', 'of', 'the', 'new', 'year', ...
#
#                                       text_token_stemmed  \
# 5944   ['within', 'the', 'past', 'year', 'congress', ...
# 10926  ['clean', 'water', 'is', 'essenti', 'yet', 'in...
# 10925  ['carpent', 'ant', 'live', 'in', 'a', 'cast', ...
# 11929  ['ok', 'well', 'admit', 'itther', 'was', 'a', ...
# 2875   ['the', 'come', 'of', 'the', 'new', 'year', 'g...
#
#                                         text_token_count
# 5944   {'within': 1, 'the': 79, 'past': 1, 'year': 5,...
# 10926  {'clean': 1, 'water': 3, 'is': 2, 'essenti': 1...
# 10925  {'carpent': 2, 'ant': 6, 'live': 1, 'in': 15, ...
# 11929  {'ok': 1, 'well': 2, 'admit': 1, 'itther': 1, ...
# 2875   {'the': 83, 'come': 2, 'of': 42, 'new': 5, 'ye...

# %% [markdown]
# ### Right now we have one list per row in the column 'text_token_stemmed'. Let's use list comprehension (more help for this online) to create a single list.

# %%
flat_list = [item for sublist in df['text_token_stemmed'].apply(literal_eval) for item in sublist]

# %% [markdown]
# #### Let's use NLTK package to remove some common stopwords from our list, e.g. 'the', 'of'.

# %%
no_stop_words_list = [word for word in flat_list if word not in stopwords.words('english')]

# %%
# count tokens 
count_tokens=Counter(no_stop_words_list)

# %% [markdown]
# #### Now we can check what are the most common tokens in our dataset

# %%
count_tokens.most_common()[:20]
# Out:
# [('use', 1080),
#  ('compani', 833),
#  ('also', 726),
#  ('new', 708),
#  ('one', 689),
#  ('year', 654),
#  ('like', 650),
#  ('would', 645),
#  ('said', 638),
#  ('time', 532),
#  ('make', 504),
#  ('could', 452),
#  ('system', 435),
#  ('us', 431),
#  ('work', 409),
#  ('research', 409),
#  ('get', 399),
#  ('includ', 392),
#  ('provid', 385),
#  ('report', 384)]

# %% [markdown]
# ### As you can clearly see they most of the are still rather generic. Assuming that our task is to identify significant tokens that would tell us story about the state of technology discussion this list would be of little help. Can you come up with a better solution to tackle this problem?

# %% [markdown]
# #### (...) OK, you have found a slightly/significantly/radically better solution. Now you'd probably like to present your meaningful results. A good old bar chart is good for starters. Let's prepare it using plotly package and our poorly filtered, 'generic' results.

# %%
bar_chart=count_tokens.most_common()[:10]

# %%
bar_chart=pd.DataFrame(bar_chart)

# %% [markdown]
# #### Bar chart

# %%
plotly.offline.plot({
"data": [
    plotly.graph_objs.Bar(x=bar_chart[0],y=bar_chart[1])
]
})
# Out:
# 'file:///Volumes/GoogleDrive/My Drive/NGI/Engineroom/analysis/temp-plot.html'

# %% [markdown]
# ## Experiment with more months
#
# ### Let's import all months for arts technica articles

# %%
all_files = glob.glob(path + '/*arstechnica.csv')
dfs = []
for file in all_files:
    df = pd.read_csv(file)
    df['month']=file.split('/')[-1].replace('dfs_articles','')[:7]
    dfs.append(df)
df = pd.concat(dfs, ignore_index=True)
df.shape
# Out:
# (12229, 10)

# %%
df['month']=pd.to_datetime(df['month'],format='%Y-%m')

# %%
#df['month'].unique()

# %% [markdown]
# #### We have data from 2016-12 to 2018-03

# %%
# Let's shorten the period to 2017-12/2018-03 for quicker calculation
df=df.loc[(df['month']>'2017-12-01')& (df['month']<'2018-04-01')]

# %%
len(df)
# Out:
# 1044

# %% [markdown]
# #### Our dataset now contains articles for a few months

# %%
df.head()
# Out:
#    Unnamed: 0  \
# 0         122
# 1         384
# 2         121
# 3         120
# 4         383
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       text  \
# 0  Microsoft and Bill & Melinda Gates Foundation progenitor Bill Gates is not a fan of cryptocurrencies. In a Reddit AMA yesterday, he posited that cryptocurrencies subvert governments' abilities to intercept terrorist funding, illegal drug transactions, and more.\n\nRedditor Askur1337 asked Gates, "Whats your opinion on Crypto Currencies?" To this, Gates responded:\n\nThe main feature of cryptocurrencies is their anonymity. I don't think this is a good thing. The government's ability to find money laundering and tax evasion and terrorist funding is a good thing. Right now, cryptocurrencies are used for buying fentanyl and other drugs, so it is a rare technology that has caused deaths in a fairly direct way. I think the speculative wave around ICOs and cryptocurrencies is super risky for those who go long.\n\nRedditor dikkepiemel followed up with a rebuttal that cryptocurrencies aren't doing anything cash wasn't already doing, saying, "The US dollar is also used to buy fentanyl and go...
# 1  Cellebrite—the Israel-based forensics company that has been a key source for law enforcement in efforts to crack the security of mobile devices to recover evidence—has reportedly found a way to unlock Apple devices using all versions of the iOS operating system up to version 11.2.6, the most recent update pushed out to customers by Apple. The capability is part of Cellebrite's Advanced Unlocking and Extraction Services, a lab-based service the company provides to law enforcement agencies—not a software product.\n\nBut security experts are dubious of any claim that Cellebrite can defeat the encryption used by iOS to protect the contents of Apple devices. Rather, they suggest Cellebrite's "Advanced Unlocking Services" may have found a way to bypass the limits on PIN or password entry enforced by interfering with the code that counts the number of failed attempts—allowing the company's lab to launch a brute-force attack to try to discover the passcode without fear of the device erasin...
# 2  \n\n\n\nOn Wednesday afternoon, US District Judge Phyllis Hamilton ordered the lead defendant, Purvis Ellis, to 20 years in prison. Ars chronicled the Ellis case more than two years ago in a lengthy feature and described how Ellis was located via the use of cell-site simulators. These devices, which spoof ordinary cell towers, are often used by police to locate criminal suspects. However, in recent years, judges nationwide have increasingly scrutinized use of the surveillance tool.\n\nEllis apologized to the court and to the judge. "I just hope not to be defined by this," he said during the sentencing hearing.\n\n\n\n\n\n“Mr. Ellis is not at all the man the government portrays him to be,” she said. “The fact of the matter is that Mr. Ellis has spent most of his life in custody. There just did not leave a lot of time for him to be associated with gang activity. Mr. Ellis is a very, very smart man. He has made real efforts since he’s been in custody to think about where he has been i...
# 3  A Google engineer says she was a frequent target of regular sexual harassment during her seven years at the company. In a lawsuit filed earlier this month, Loretta Lee (no relation) accused the Mountain View company of having a "bro-culture" that was hostile to women—and of doing too little to address the problem.\n\nThe lawsuit is the latest headache from a company that has faced complaints from both sides of the culture war. Last year, Google fired engineer James Damore after he wrote a controversial memo arguing that the under-representation of women at the company might be due to women's lack of interest in computer programming. He responded by suing Google for allegedly discriminating against men.\n\nBut others have filed lawsuits making the opposite charge: that Google's culture is too hostile toward women—and to men who spoken out against that culture. Three women sued Google in September, charging that Google had systematically channeled female engineers into less lucrative...
# 4  A major dust-up on an Internet discussion forum is touching off troubling questions about the security of some browser-trusted HTTPS certificates when it revealed the CEO of a certificate reseller emailed a partner the sensitive private keys for 23,000 TLS certificates.\n\n\n\n\n\nWhen Rowley asked for proof the certificates were compromised, the Trustico CEO emailed the private keys of 23,000 certificates, according to an account posted to a Mozilla security policy forum. The report produced a collective gasp among many security practitioners who said it demonstrated a shockingly cavalier treatment of the digital certificates that form one of the most basic foundations of website security.\n\nGenerally speaking, private keys for TLS certificates should never be archived by resellers, and, even in the rare cases where such storage is permissible, they should be tightly safeguarded. A CEO being able to attach the keys for 23,000 certificates to an email raises troubling concerns tha...
#
#            author         site  \
# 0     SAMUEL AXON  arstechnica
# 1  SEAN GALLAGHER  arstechnica
# 2   CYRUS FARIVAR  arstechnica
# 3  TIMOTHY B. LEE  arstechnica
# 4      DAN GOODIN  arstechnica
#
#                                                                                                                        link  \
# 0   https://arstechnica.com/tech-policy/2018/02/bill-gates-says-cryptocurrencies-have-caused-deaths-in-a-fairly-direct-way/
# 1           https://arstechnica.com/information-technology/2018/02/cellebrite-can-unlock-any-iphone-for-some-values-of-any/
# 2  https://arstechnica.com/tech-policy/2018/03/lead-defendant-in-attempted-murder-case-located-via-stingray-given-20-years/
# 3                  https://arstechnica.com/tech-policy/2018/03/google-turned-a-blind-eye-to-toxic-bro-culture-lawsuit-says/
# 4      https://arstechnica.com/information-technology/2018/03/23000-https-certificates-axed-after-ceo-e-mails-private-keys/
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 text_token  \
# 0  ['Microsoft', 'and', 'Bill', 'Melinda', 'Gates', 'Foundation', 'progenitor', 'Bill', 'Gates', 'is', 'not', 'a', 'fan', 'of', 'cryptocurrencies', 'In', 'a', 'Reddit', 'AMA', 'yesterday', 'he', 'posited', 'that', 'cryptocurrencies', 'subvert', 'governments', 'abilities', 'to', 'intercept', 'terrorist', 'funding', 'illegal', 'drug', 'transactions', 'and', 'more', 'Redditor', 'Askur1337', 'asked', 'Gates', 'Whats', 'your', 'opinion', 'on', 'Crypto', 'Currencies', 'To', 'this', 'Gates', 'responded', 'The', 'main', 'feature', 'of', 'cryptocurrencies', 'is', 'their', 'anonymity', 'I', 'dont', 'think', 'this', 'is', 'a', 'good', 'thing', 'The', 'governments', 'ability', 'to', 'find', 'money', 'laundering', 'and', 'tax', 'evasion', 'and', 'terrorist', 'funding', 'is', 'a', 'good', 'thing', 'Right', 'now', 'cryptocurrencies', 'are', 'used', 'for', 'buying', 'fentanyl', 'and', 'other', 'drugs', 'so', 'it', 'is', 'a', 'rare', 'technology', 'that', 'has', 'caused', 'deaths', 'in', 'a', 'fairly'...
# 1  ['Cellebritethe', 'Israelbased', 'forensics', 'company', 'that', 'has', 'been', 'a', 'key', 'source', 'for', 'law', 'enforcement', 'in', 'efforts', 'to', 'crack', 'the', 'security', 'of', 'mobile', 'devices', 'to', 'recover', 'evidencehas', 'reportedly', 'found', 'a', 'way', 'to', 'unlock', 'Apple', 'devices', 'using', 'all', 'versions', 'of', 'the', 'iOS', 'operating', 'system', 'up', 'to', 'version', '1126', 'the', 'most', 'recent', 'update', 'pushed', 'out', 'to', 'customers', 'by', 'Apple', 'The', 'capability', 'is', 'part', 'of', 'Cellebrites', 'Advanced', 'Unlocking', 'and', 'Extraction', 'Services', 'a', 'labbased', 'service', 'the', 'company', 'provides', 'to', 'law', 'enforcement', 'agenciesnot', 'a', 'software', 'product', 'But', 'security', 'experts', 'are', 'dubious', 'of', 'any', 'claim', 'that', 'Cellebrite', 'can', 'defeat', 'the', 'encryption', 'used', 'by', 'iOS', 'to', 'protect', 'the', 'contents', 'of', 'Apple', 'devices', 'Rather', 'they', 'suggest', 'Cellebrite...
# 2  ['On', 'Wednesday', 'afternoon', 'US', 'District', 'Judge', 'Phyllis', 'Hamilton', 'ordered', 'the', 'lead', 'defendant', 'Purvis', 'Ellis', 'to', '20', 'years', 'in', 'prison', 'Ars', 'chronicled', 'the', 'Ellis', 'case', 'more', 'than', 'two', 'years', 'ago', 'in', 'a', 'lengthy', 'feature', 'and', 'described', 'how', 'Ellis', 'was', 'located', 'via', 'the', 'use', 'of', 'cellsite', 'simulators', 'These', 'devices', 'which', 'spoof', 'ordinary', 'cell', 'towers', 'are', 'often', 'used', 'by', 'police', 'to', 'locate', 'criminal', 'suspects', 'However', 'in', 'recent', 'years', 'judges', 'nationwide', 'have', 'increasingly', 'scrutinized', 'use', 'of', 'the', 'surveillance', 'tool', 'Ellis', 'apologized', 'to', 'the', 'court', 'and', 'to', 'the', 'judge', 'I', 'just', 'hope', 'not', 'to', 'be', 'defined', 'by', 'this', 'he', 'said', 'during', 'the', 'sentencing', 'hearing', 'Mr', 'Ellis', 'is', 'not', 'at', 'all', 'the', 'man', 'the', 'government', 'portrays', 'him', 'to', 'be', '...
# 3  ['A', 'Google', 'engineer', 'says', 'she', 'was', 'a', 'frequent', 'target', 'of', 'regular', 'sexual', 'harassment', 'during', 'her', 'seven', 'years', 'at', 'the', 'company', 'In', 'a', 'lawsuit', 'filed', 'earlier', 'this', 'month', 'Loretta', 'Lee', 'no', 'relation', 'accused', 'the', 'Mountain', 'View', 'company', 'of', 'having', 'a', 'broculture', 'that', 'was', 'hostile', 'to', 'womenand', 'of', 'doing', 'too', 'little', 'to', 'address', 'the', 'problem', 'The', 'lawsuit', 'is', 'the', 'latest', 'headache', 'from', 'a', 'company', 'that', 'has', 'faced', 'complaints', 'from', 'both', 'sides', 'of', 'the', 'culture', 'war', 'Last', 'year', 'Google', 'fired', 'engineer', 'James', 'Damore', 'after', 'he', 'wrote', 'a', 'controversial', 'memo', 'arguing', 'that', 'the', 'underrepresentation', 'of', 'women', 'at', 'the', 'company', 'might', 'be', 'due', 'to', 'womens', 'lack', 'of', 'interest', 'in', 'computer', 'programming', 'He', 'responded', 'by', 'suing', 'Google', 'for', 'a...
# 4  ['A', 'major', 'dustup', 'on', 'an', 'Internet', 'discussion', 'forum', 'is', 'touching', 'off', 'troubling', 'questions', 'about', 'the', 'security', 'of', 'some', 'browsertrusted', 'HTTPS', 'certificates', 'when', 'it', 'revealed', 'the', 'CEO', 'of', 'a', 'certificate', 'reseller', 'emailed', 'a', 'partner', 'the', 'sensitive', 'private', 'keys', 'for', '23000', 'TLS', 'certificates', 'When', 'Rowley', 'asked', 'for', 'proof', 'the', 'certificates', 'were', 'compromised', 'the', 'Trustico', 'CEO', 'emailed', 'the', 'private', 'keys', 'of', '23000', 'certificates', 'according', 'to', 'an', 'account', 'posted', 'to', 'a', 'Mozilla', 'security', 'policy', 'forum', 'The', 'report', 'produced', 'a', 'collective', 'gasp', 'among', 'many', 'security', 'practitioners', 'who', 'said', 'it', 'demonstrated', 'a', 'shockingly', 'cavalier', 'treatment', 'of', 'the', 'digital', 'certificates', 'that', 'form', 'one', 'of', 'the', 'most', 'basic', 'foundations', 'of', 'website', 'security', 'Ge...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           text_token_lower  \
# 0  ['microsoft', 'and', 'bill', 'melinda', 'gates', 'foundation', 'progenitor', 'bill', 'gates', 'is', 'not', 'a', 'fan', 'of', 'cryptocurrencies', 'in', 'a', 'reddit', 'ama', 'yesterday', 'he', 'posited', 'that', 'cryptocurrencies', 'subvert', 'governments', 'abilities', 'to', 'intercept', 'terrorist', 'funding', 'illegal', 'drug', 'transactions', 'and', 'more', 'redditor', 'askur1337', 'asked', 'gates', 'whats', 'your', 'opinion', 'on', 'crypto', 'currencies', 'to', 'this', 'gates', 'responded', 'the', 'main', 'feature', 'of', 'cryptocurrencies', 'is', 'their', 'anonymity', 'i', 'dont', 'think', 'this', 'is', 'a', 'good', 'thing', 'the', 'governments', 'ability', 'to', 'find', 'money', 'laundering', 'and', 'tax', 'evasion', 'and', 'terrorist', 'funding', 'is', 'a', 'good', 'thing', 'right', 'now', 'cryptocurrencies', 'are', 'used', 'for', 'buying', 'fentanyl', 'and', 'other', 'drugs', 'so', 'it', 'is', 'a', 'rare', 'technology', 'that', 'has', 'caused', 'deaths', 'in', 'a', 'fairly'...
# 1  ['cellebritethe', 'israelbased', 'forensics', 'company', 'that', 'has', 'been', 'a', 'key', 'source', 'for', 'law', 'enforcement', 'in', 'efforts', 'to', 'crack', 'the', 'security', 'of', 'mobile', 'devices', 'to', 'recover', 'evidencehas', 'reportedly', 'found', 'a', 'way', 'to', 'unlock', 'apple', 'devices', 'using', 'all', 'versions', 'of', 'the', 'ios', 'operating', 'system', 'up', 'to', 'version', '1126', 'the', 'most', 'recent', 'update', 'pushed', 'out', 'to', 'customers', 'by', 'apple', 'the', 'capability', 'is', 'part', 'of', 'cellebrites', 'advanced', 'unlocking', 'and', 'extraction', 'services', 'a', 'labbased', 'service', 'the', 'company', 'provides', 'to', 'law', 'enforcement', 'agenciesnot', 'a', 'software', 'product', 'but', 'security', 'experts', 'are', 'dubious', 'of', 'any', 'claim', 'that', 'cellebrite', 'can', 'defeat', 'the', 'encryption', 'used', 'by', 'ios', 'to', 'protect', 'the', 'contents', 'of', 'apple', 'devices', 'rather', 'they', 'suggest', 'cellebrite...
# 2  ['on', 'wednesday', 'afternoon', 'us', 'district', 'judge', 'phyllis', 'hamilton', 'ordered', 'the', 'lead', 'defendant', 'purvis', 'ellis', 'to', '20', 'years', 'in', 'prison', 'ars', 'chronicled', 'the', 'ellis', 'case', 'more', 'than', 'two', 'years', 'ago', 'in', 'a', 'lengthy', 'feature', 'and', 'described', 'how', 'ellis', 'was', 'located', 'via', 'the', 'use', 'of', 'cellsite', 'simulators', 'these', 'devices', 'which', 'spoof', 'ordinary', 'cell', 'towers', 'are', 'often', 'used', 'by', 'police', 'to', 'locate', 'criminal', 'suspects', 'however', 'in', 'recent', 'years', 'judges', 'nationwide', 'have', 'increasingly', 'scrutinized', 'use', 'of', 'the', 'surveillance', 'tool', 'ellis', 'apologized', 'to', 'the', 'court', 'and', 'to', 'the', 'judge', 'i', 'just', 'hope', 'not', 'to', 'be', 'defined', 'by', 'this', 'he', 'said', 'during', 'the', 'sentencing', 'hearing', 'mr', 'ellis', 'is', 'not', 'at', 'all', 'the', 'man', 'the', 'government', 'portrays', 'him', 'to', 'be', '...
# 3  ['a', 'google', 'engineer', 'says', 'she', 'was', 'a', 'frequent', 'target', 'of', 'regular', 'sexual', 'harassment', 'during', 'her', 'seven', 'years', 'at', 'the', 'company', 'in', 'a', 'lawsuit', 'filed', 'earlier', 'this', 'month', 'loretta', 'lee', 'no', 'relation', 'accused', 'the', 'mountain', 'view', 'company', 'of', 'having', 'a', 'broculture', 'that', 'was', 'hostile', 'to', 'womenand', 'of', 'doing', 'too', 'little', 'to', 'address', 'the', 'problem', 'the', 'lawsuit', 'is', 'the', 'latest', 'headache', 'from', 'a', 'company', 'that', 'has', 'faced', 'complaints', 'from', 'both', 'sides', 'of', 'the', 'culture', 'war', 'last', 'year', 'google', 'fired', 'engineer', 'james', 'damore', 'after', 'he', 'wrote', 'a', 'controversial', 'memo', 'arguing', 'that', 'the', 'underrepresentation', 'of', 'women', 'at', 'the', 'company', 'might', 'be', 'due', 'to', 'womens', 'lack', 'of', 'interest', 'in', 'computer', 'programming', 'he', 'responded', 'by', 'suing', 'google', 'for', 'a...
# 4  ['a', 'major', 'dustup', 'on', 'an', 'internet', 'discussion', 'forum', 'is', 'touching', 'off', 'troubling', 'questions', 'about', 'the', 'security', 'of', 'some', 'browsertrusted', 'https', 'certificates', 'when', 'it', 'revealed', 'the', 'ceo', 'of', 'a', 'certificate', 'reseller', 'emailed', 'a', 'partner', 'the', 'sensitive', 'private', 'keys', 'for', '23000', 'tls', 'certificates', 'when', 'rowley', 'asked', 'for', 'proof', 'the', 'certificates', 'were', 'compromised', 'the', 'trustico', 'ceo', 'emailed', 'the', 'private', 'keys', 'of', '23000', 'certificates', 'according', 'to', 'an', 'account', 'posted', 'to', 'a', 'mozilla', 'security', 'policy', 'forum', 'the', 'report', 'produced', 'a', 'collective', 'gasp', 'among', 'many', 'security', 'practitioners', 'who', 'said', 'it', 'demonstrated', 'a', 'shockingly', 'cavalier', 'treatment', 'of', 'the', 'digital', 'certificates', 'that', 'form', 'one', 'of', 'the', 'most', 'basic', 'foundations', 'of', 'website', 'security', 'ge...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         text_token_stemmed  \
# 0  ['microsoft', 'and', 'bill', 'melinda', 'gate', 'foundat', 'progenitor', 'bill', 'gate', 'is', 'not', 'a', 'fan', 'of', 'cryptocurr', 'in', 'a', 'reddit', 'ama', 'yesterday', 'he', 'posit', 'that', 'cryptocurr', 'subvert', 'govern', 'abil', 'to', 'intercept', 'terrorist', 'fund', 'illeg', 'drug', 'transact', 'and', 'more', 'redditor', 'askur1337', 'ask', 'gate', 'what', 'your', 'opinion', 'on', 'crypto', 'currenc', 'to', 'this', 'gate', 'respond', 'the', 'main', 'featur', 'of', 'cryptocurr', 'is', 'their', 'anonym', 'i', 'dont', 'think', 'this', 'is', 'a', 'good', 'thing', 'the', 'govern', 'abil', 'to', 'find', 'money', 'launder', 'and', 'tax', 'evas', 'and', 'terrorist', 'fund', 'is', 'a', 'good', 'thing', 'right', 'now', 'cryptocurr', 'are', 'use', 'for', 'buy', 'fentanyl', 'and', 'other', 'drug', 'so', 'it', 'is', 'a', 'rare', 'technolog', 'that', 'has', 'caus', 'death', 'in', 'a', 'fair', 'direct', 'way', 'i', 'think', 'the', 'specul', 'wave', 'around', 'ico', 'and', 'cryptocur...
# 1  ['cellebriteth', 'israelbas', 'forens', 'compani', 'that', 'has', 'been', 'a', 'key', 'sourc', 'for', 'law', 'enforc', 'in', 'effort', 'to', 'crack', 'the', 'secur', 'of', 'mobil', 'devic', 'to', 'recov', 'evidenceha', 'report', 'found', 'a', 'way', 'to', 'unlock', 'appl', 'devic', 'use', 'all', 'version', 'of', 'the', 'io', 'oper', 'system', 'up', 'to', 'version', '1126', 'the', 'most', 'recent', 'updat', 'push', 'out', 'to', 'custom', 'by', 'appl', 'the', 'capabl', 'is', 'part', 'of', 'cellebrit', 'advanc', 'unlock', 'and', 'extract', 'servic', 'a', 'labbas', 'servic', 'the', 'compani', 'provid', 'to', 'law', 'enforc', 'agenciesnot', 'a', 'softwar', 'product', 'but', 'secur', 'expert', 'are', 'dubious', 'of', 'ani', 'claim', 'that', 'cellebrit', 'can', 'defeat', 'the', 'encrypt', 'use', 'by', 'io', 'to', 'protect', 'the', 'content', 'of', 'appl', 'devic', 'rather', 'they', 'suggest', 'cellebrit', 'advanc', 'unlock', 'servic', 'may', 'have', 'found', 'a', 'way', 'to', 'bypass', 't...
# 2  ['on', 'wednesday', 'afternoon', 'us', 'district', 'judg', 'phylli', 'hamilton', 'order', 'the', 'lead', 'defend', 'purvi', 'elli', 'to', '20', 'year', 'in', 'prison', 'ar', 'chronicl', 'the', 'elli', 'case', 'more', 'than', 'two', 'year', 'ago', 'in', 'a', 'lengthi', 'featur', 'and', 'describ', 'how', 'elli', 'was', 'locat', 'via', 'the', 'use', 'of', 'cellsit', 'simul', 'these', 'devic', 'which', 'spoof', 'ordinari', 'cell', 'tower', 'are', 'often', 'use', 'by', 'polic', 'to', 'locat', 'crimin', 'suspect', 'howev', 'in', 'recent', 'year', 'judg', 'nationwid', 'have', 'increas', 'scrutin', 'use', 'of', 'the', 'surveil', 'tool', 'elli', 'apolog', 'to', 'the', 'court', 'and', 'to', 'the', 'judg', 'i', 'just', 'hope', 'not', 'to', 'be', 'defin', 'by', 'this', 'he', 'said', 'dure', 'the', 'sentenc', 'hear', 'mr', 'elli', 'is', 'not', 'at', 'all', 'the', 'man', 'the', 'govern', 'portray', 'him', 'to', 'be', 'she', 'said', 'the', 'fact', 'of', 'the', 'matter', 'is', 'that', 'mr', 'elli'...
# 3  ['a', 'googl', 'engin', 'say', 'she', 'was', 'a', 'frequent', 'target', 'of', 'regular', 'sexual', 'harass', 'dure', 'her', 'seven', 'year', 'at', 'the', 'compani', 'in', 'a', 'lawsuit', 'file', 'earlier', 'this', 'month', 'loretta', 'lee', 'no', 'relat', 'accus', 'the', 'mountain', 'view', 'compani', 'of', 'have', 'a', 'brocultur', 'that', 'was', 'hostil', 'to', 'womenand', 'of', 'do', 'too', 'littl', 'to', 'address', 'the', 'problem', 'the', 'lawsuit', 'is', 'the', 'latest', 'headach', 'from', 'a', 'compani', 'that', 'has', 'face', 'complaint', 'from', 'both', 'side', 'of', 'the', 'cultur', 'war', 'last', 'year', 'googl', 'fire', 'engin', 'jame', 'damor', 'after', 'he', 'wrote', 'a', 'controversi', 'memo', 'argu', 'that', 'the', 'underrepresent', 'of', 'women', 'at', 'the', 'compani', 'might', 'be', 'due', 'to', 'women', 'lack', 'of', 'interest', 'in', 'comput', 'program', 'he', 'respond', 'by', 'su', 'googl', 'for', 'alleg', 'discrimin', 'against', 'men', 'but', 'other', 'have',...
# 4  ['a', 'major', 'dustup', 'on', 'an', 'internet', 'discuss', 'forum', 'is', 'touch', 'off', 'troubl', 'question', 'about', 'the', 'secur', 'of', 'some', 'browsertrust', 'https', 'certif', 'when', 'it', 'reveal', 'the', 'ceo', 'of', 'a', 'certif', 'resel', 'email', 'a', 'partner', 'the', 'sensit', 'privat', 'key', 'for', '23000', 'tls', 'certif', 'when', 'rowley', 'ask', 'for', 'proof', 'the', 'certif', 'were', 'compromis', 'the', 'trustico', 'ceo', 'email', 'the', 'privat', 'key', 'of', '23000', 'certif', 'accord', 'to', 'an', 'account', 'post', 'to', 'a', 'mozilla', 'secur', 'polici', 'forum', 'the', 'report', 'produc', 'a', 'collect', 'gasp', 'among', 'mani', 'secur', 'practition', 'who', 'said', 'it', 'demonstr', 'a', 'shock', 'cavali', 'treatment', 'of', 'the', 'digit', 'certif', 'that', 'form', 'one', 'of', 'the', 'most', 'basic', 'foundat', 'of', 'websit', 'secur', 'general', 'speak', 'privat', 'key', 'for', 'tls', 'certif', 'should', 'never', 'be', 'archiv', 'by', 'resel', 'a...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           text_token_count  \
# 0  {'microsoft': 1, 'and': 11, 'bill': 3, 'melinda': 1, 'gate': 10, 'foundat': 1, 'progenitor': 1, 'is': 16, 'not': 7, 'a': 11, 'fan': 1, 'of': 16, 'cryptocurr': 13, 'in': 9, 'reddit': 1, 'ama': 1, 'yesterday': 1, 'he': 1, 'posit': 1, 'that': 9, 'subvert': 1, 'govern': 3, 'abil': 2, 'to': 19, 'intercept': 1, 'terrorist': 2, 'fund': 2, 'illeg': 1, 'drug': 3, 'transact': 1, 'more': 3, 'redditor': 3, 'askur1337': 1, 'ask': 1, 'what': 2, 'your': 2, 'opinion': 1, 'on': 2, 'crypto': 3, 'currenc': 3, 'this': 3, 'respond': 2, 'the': 20, 'main': 2, 'featur': 2, 'their': 2, 'anonym': 2, 'i': 2, 'dont': 1, 'think': 2, 'good': 2, 'thing': 4, 'find': 1, 'money': 2, 'launder': 2, 'tax': 1, 'evas': 1, 'right': 1, 'now': 2, 'are': 2, 'use': 5, 'for': 8, 'buy': 2, 'fentanyl': 4, 'other': 2, 'so': 2, 'it': 4, 'rare': 1, 'technolog': 2, 'has': 4, 'caus': 1, 'death': 3, 'fair': 2, 'direct': 3, 'way': 1, 'specul': 1, 'wave': 1, 'around': 1, 'ico': 1, 'super': 1, 'riski': 1, 'those': 2, 'who': 3, 'go': 1, ...
# 1  {'cellebriteth': 1, 'israelbas': 1, 'forens': 1, 'compani': 3, 'that': 14, 'has': 3, 'been': 2, 'a': 18, 'key': 2, 'sourc': 1, 'for': 4, 'law': 2, 'enforc': 3, 'in': 6, 'effort': 1, 'to': 29, 'crack': 1, 'the': 47, 'secur': 7, 'of': 20, 'mobil': 1, 'devic': 10, 'recov': 3, 'evidenceha': 1, 'report': 2, 'found': 3, 'way': 3, 'unlock': 8, 'appl': 5, 'use': 5, 'all': 2, 'version': 2, 'io': 3, 'oper': 2, 'system': 4, 'up': 2, '1126': 1, 'most': 1, 'recent': 1, 'updat': 2, 'push': 1, 'out': 1, 'custom': 1, 'by': 5, 'capabl': 1, 'is': 9, 'part': 1, 'cellebrit': 13, 'advanc': 4, 'and': 12, 'extract': 1, 'servic': 5, 'labbas': 1, 'provid': 2, 'agenciesnot': 1, 'softwar': 3, 'product': 1, 'but': 2, 'expert': 1, 'are': 1, 'dubious': 1, 'ani': 2, 'claim': 2, 'can': 7, 'defeat': 1, 'encrypt': 2, 'protect': 2, 'content': 2, 'rather': 1, 'they': 3, 'suggest': 1, 'may': 2, 'have': 4, 'bypass': 3, 'limit': 2, 'on': 4, 'pin': 5, 'or': 6, 'password': 4, 'entri': 1, 'interf': 1, 'with': 5, 'code': 1,...
# 2  {'on': 2, 'wednesday': 2, 'afternoon': 1, 'us': 2, 'district': 1, 'judg': 3, 'phylli': 1, 'hamilton': 1, 'order': 1, 'the': 35, 'lead': 1, 'defend': 1, 'purvi': 1, 'elli': 10, 'to': 19, '20': 1, 'year': 5, 'in': 13, 'prison': 1, 'ar': 1, 'chronicl': 1, 'case': 1, 'more': 2, 'than': 2, 'two': 1, 'ago': 1, 'a': 6, 'lengthi': 1, 'featur': 1, 'and': 15, 'describ': 1, 'how': 1, 'was': 5, 'locat': 2, 'via': 1, 'use': 4, 'of': 12, 'cellsit': 1, 'simul': 1, 'these': 2, 'devic': 1, 'which': 1, 'spoof': 1, 'ordinari': 1, 'cell': 1, 'tower': 1, 'are': 1, 'often': 1, 'by': 2, 'polic': 2, 'crimin': 4, 'suspect': 2, 'howev': 1, 'recent': 1, 'nationwid': 1, 'have': 1, 'increas': 1, 'scrutin': 1, 'surveil': 1, 'tool': 1, 'apolog': 2, 'court': 2, 'i': 5, 'just': 3, 'hope': 1, 'not': 6, 'be': 5, 'defin': 1, 'this': 3, 'he': 7, 'said': 4, 'dure': 1, 'sentenc': 5, 'hear': 2, 'mr': 3, 'is': 4, 'at': 4, 'all': 2, 'man': 2, 'govern': 1, 'portray': 1, 'him': 3, 'she': 1, 'fact': 1, 'matter': 1, 'that': 8,...
# 3  {'a': 26, 'googl': 13, 'engin': 5, 'say': 5, 'she': 17, 'was': 10, 'frequent': 2, 'target': 1, 'of': 16, 'regular': 1, 'sexual': 4, 'harass': 3, 'dure': 2, 'her': 19, 'seven': 1, 'year': 4, 'at': 5, 'the': 32, 'compani': 6, 'in': 11, 'lawsuit': 7, 'file': 4, 'earlier': 2, 'this': 5, 'month': 5, 'loretta': 1, 'lee': 15, 'no': 3, 'relat': 1, 'accus': 1, 'mountain': 1, 'view': 1, 'have': 5, 'brocultur': 3, 'that': 19, 'hostil': 2, 'to': 22, 'womenand': 2, 'do': 4, 'too': 2, 'littl': 2, 'address': 1, 'problem': 3, 'is': 3, 'latest': 1, 'headach': 1, 'from': 4, 'has': 1, 'face': 4, 'complaint': 4, 'both': 1, 'side': 1, 'cultur': 5, 'war': 1, 'last': 1, 'fire': 1, 'jame': 1, 'damor': 2, 'after': 2, 'he': 6, 'wrote': 4, 'controversi': 1, 'memo': 2, 'argu': 1, 'underrepresent': 1, 'women': 4, 'might': 1, 'be': 2, 'due': 1, 'lack': 2, 'interest': 1, 'comput': 1, 'program': 1, 'respond': 1, 'by': 3, 'su': 3, 'for': 5, 'alleg': 3, 'discrimin': 2, 'against': 3, 'men': 3, 'but': 2, 'other': 1, ...
# 4  {'a': 16, 'major': 1, 'dustup': 1, 'on': 3, 'an': 6, 'internet': 2, 'discuss': 3, 'forum': 3, 'is': 3, 'touch': 1, 'off': 1, 'troubl': 2, 'question': 5, 'about': 3, 'the': 38, 'secur': 7, 'of': 12, 'some': 1, 'browsertrust': 2, 'https': 1, 'certif': 22, 'when': 5, 'it': 10, 'reveal': 1, 'ceo': 3, 'resel': 8, 'email': 7, 'partner': 1, 'sensit': 1, 'privat': 6, 'key': 9, 'for': 10, '23000': 3, 'tls': 4, 'rowley': 1, 'ask': 1, 'proof': 1, 'were': 4, 'compromis': 3, 'trustico': 12, 'accord': 1, 'to': 27, 'account': 4, 'post': 2, 'mozilla': 3, 'polici': 1, 'report': 1, 'produc': 1, 'collect': 1, 'gasp': 1, 'among': 1, 'mani': 3, 'practition': 1, 'who': 1, 'said': 2, 'demonstr': 2, 'shock': 1, 'cavali': 1, 'treatment': 1, 'digit': 1, 'that': 11, 'form': 1, 'one': 1, 'most': 1, 'basic': 1, 'foundat': 1, 'websit': 2, 'general': 1, 'speak': 1, 'should': 2, 'never': 1, 'be': 4, 'archiv': 2, 'by': 1, 'and': 9, 'even': 1, 'in': 8, 'rare': 1, 'case': 1, 'where': 1, 'such': 1, 'storag': 4, 'perm...
#
#        month
# 0 2018-03-01
# 1 2018-03-01
# 2 2018-03-01
# 3 2018-03-01
# 4 2018-03-01

# %%
df['text_token_stemmed'] = df['text_token_stemmed'].apply(literal_eval) #We need to apply literal_eval so that Python knows we are dealing with words

# %% [markdown]
# #### Let's group articles by month for further analysis

# %%
df_gr=df.groupby('month')['text_token_stemmed'].sum()

# %%
df=pd.DataFrame(df_gr)

# %%
df.reset_index(inplace=True, drop=False)

# %%
df #our dataset contains now aggaregated text for every month
# Out:
#        month                                 text_token_stemmed
# 0 2018-01-01  [on, novemb, 3, 2007, six, vehicl, made, histo...
# 1 2018-02-01  [microsoft, has, post, the, result, of, the, s...
# 2 2018-03-01  [microsoft, and, bill, melinda, gate, foundat,...

# %%
df['no_stop_words']=df['text_token_stemmed'].apply(lambda x: [item for item in x if item not in stopwords.words('english')]) #This will count for a few minutes

# %%
df.head()
# Out:
#        month                                 text_token_stemmed  \
# 0 2018-01-01  [on, novemb, 3, 2007, six, vehicl, made, histo...
# 1 2018-02-01  [microsoft, has, post, the, result, of, the, s...
# 2 2018-03-01  [microsoft, and, bill, melinda, gate, foundat,...
#
#                                        no_stop_words
# 0  [novemb, 3, 2007, six, vehicl, made, histori, ...
# 1  [microsoft, post, result, second, quarter, 201...
# 2  [microsoft, bill, melinda, gate, foundat, prog...

# %%
df['counts']=df['no_stop_words'].apply(lambda x: Counter(x)) # Let's calculate the words

# %%
df['counts'] # this shows by month word frequency
# Out:
# 0    {'shanti': 1, '47mm': 1, 'vmware': 7, 'matrix'...
# 1    {'antifung': 1, 'diseas': 35, 'examplebut': 1,...
# 2    {'cda': 1, 'pedalsmak': 1, 'cathod': 5, 'antif...
# Name: counts, dtype: object

# %% [markdown]
# ### Let's analyse for a keyword of interest how frequency changed over time

# %%
keyword='blockchain'
df['keyword']=df['counts'].apply(lambda x: x.get(keyword, 0))

# %%
df.head()  #so our keyword appeared 25 times in december and 9 times in march
# Out:
#        month                                 text_token_stemmed  \
# 0 2018-01-01  [on, novemb, 3, 2007, six, vehicl, made, histo...
# 1 2018-02-01  [microsoft, has, post, the, result, of, the, s...
# 2 2018-03-01  [microsoft, and, bill, melinda, gate, foundat,...
#
#                                        no_stop_words  \
# 0  [novemb, 3, 2007, six, vehicl, made, histori, ...
# 1  [microsoft, post, result, second, quarter, 201...
# 2  [microsoft, bill, melinda, gate, foundat, prog...
#
#                                               counts  keyword
# 0  {'shanti': 1, '47mm': 1, 'vmware': 7, 'matrix'...       32
# 1  {'antifung': 1, 'diseas': 35, 'examplebut': 1,...       32
# 2  {'cda': 1, 'pedalsmak': 1, 'cathod': 5, 'antif...        9

# %% [markdown]
# ### For a more thorough analysis we should not restrict ourselves for only selected keywords. Let's calculate changes over time for all words!

# %%
x=pd.DataFrame(columns=['index'])
for i in range(len(df)):
    y=pd.DataFrame.from_dict(df['counts'][i], orient='index').reset_index()
    y.rename(columns={0:df['month'][i]},inplace=True)
    x=pd.merge(x,y,on='index',how='outer')

# %%
x.head() #this df shows us the frequencies for every word
# Out:
#     index  2018-01-01 00:00:00  2018-02-01 00:00:00  2018-03-01 00:00:00
# 0  shanti                  1.0                  NaN                  NaN
# 1    47mm                  1.0                  NaN                  NaN
# 2  vmware                  7.0                  NaN                  NaN
# 3  matrix                  2.0                  5.0                  NaN
# 4  diseas                 21.0                 35.0                 14.0

# %%
x['p_diff']=(x.iloc[:,-1]-x.iloc[:,1])/x.iloc[:,1]*100 # p_diff shows us the percentage change between the first and last months in our dataset

# %%
x.head()
# Out:
#     index  2018-01-01 00:00:00  2018-02-01 00:00:00  2018-03-01 00:00:00  \
# 0  shanti                  1.0                  NaN                  NaN
# 1    47mm                  1.0                  NaN                  NaN
# 2  vmware                  7.0                  NaN                  NaN
# 3  matrix                  2.0                  5.0                  NaN
# 4  diseas                 21.0                 35.0                 14.0
#
#       p_diff
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4 -33.333333

# %%
## some transformations before the visualisations

x=x.sort_values(by='p_diff', ascending=False)
x=x.transpose()
x.rename(columns=x.iloc[0],inplace=True)
x=x[1:]
x.drop(x.tail(1).index,inplace=True) # drop last n rows
multi_line=x.iloc[:,:7]

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-155-401b30e3b8b5> in <module>()
# ----> 1 x
#
# NameError: name 'x' is not defined

# %% [markdown]
# ### Sometimes at first glance identified keywords might seem irrelevant but when you check them more closely they turn out to be significant. This is such a case. Consider 'versa' or 'lifelin' tokens. I didn't connect them with new technologies in the beginning but after brief googling them it appears that Versa is a new model of smartwatch and Lifeline is an important US subsidy programme in the Telecommunications industry.

# %%
iplot(multi_line.iplot(asFigure=True,
                               kind='scatter',xTitle='Months',yTitle='Counts',title=''))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-8f17e1ea3cb2> in <module>()
# ----> 1 iplot(multi_line.iplot(asFigure=True,
#       2                                kind='scatter',xTitle='Months',yTitle='Counts',title=''))
#
# NameError: name 'multi_line' is not defined

# %% [markdown]
# # Part II
#
# ## Working with processed text date
# ### Here we will not use the raw text data, but the calculated word frequencies in the raw data
#
# #### Analysis based on the frequency of appearances for all unigrams and bigrams in the texts
# #### Frequency: number of appearances of every term divided by the number of published articles (for every month and source)
# #### This measure reveals how many times an expression has been mentioned on average per article
# #### Several media sources: a representative index is calculated with weighted average
# #### coef: Average monthly change in the analised term's frequency is calculated by OLS regressions
# #### The dependent variable of the estimation is the frequency index, while the number of months since the beginning of the analysed period (January 2016) is the independent variable
# #### Coef shows by how much on average the analysed expression’s frequency changed with every observed month (marginal change of the frequency), revealing which keywords had the biggest monthly growth
# #### Coef_norm and coef_norm_mx are the normalised form of coef

# %%
# Let's import the data with coefficients calculated based on tokenised unigrams
path='/../res_0909/coefs_1weighted_site.csv'

# %%
df=pd.read_csv(path, index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-257-72eceb36b3e7> in <module>()
# ----> 1 df=pd.read_csv(path, index_col=0)
#
# ~/miniconda3/envs/myPython/lib/python3.5/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# ~/miniconda3/envs/myPython/lib/python3.5/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# ~/miniconda3/envs/myPython/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     762             self.options['has_index_names'] = kwds['has_index_names']
#     763
# --> 764         self._make_engine(self.engine)
#     765
#     766     def close(self):
#
# ~/miniconda3/envs/myPython/lib/python3.5/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     983     def _make_engine(self, engine='c'):
#     984         if engine == 'c':
# --> 985             self._engine = CParserWrapper(self.f, **self.options)
#     986         else:
#     987             if engine == 'python':
#
# ~/miniconda3/envs/myPython/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1603         kwds['allow_leading_cols'] = self.index_col is not False
#    1604
# -> 1605         self._reader = parsers.TextReader(src, **kwds)
#    1606
#    1607         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas/_libs/parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas/_libs/parsers.c:8873)()
#
# FileNotFoundError: File b'/.../res_0909/coefs_1weighted_site.csv' does not exist

# %%
#columns of our data frame (df)
df.columns #As you can see, we have calculated the frequency for very word
# Out:
# Index(['freq_2018-08', 'freq_2018-07', 'freq_2018-06', 'freq_2018-05',
#        'freq_2018-04', 'freq_2018-03', 'freq_2018-02', 'freq_2018-01',
#        'freq_2017-12', 'freq_2017-11', 'freq_2017-10', 'freq_2017-09',
#        'freq_2017-08', 'freq_2017-07', 'freq_2017-06', 'freq_2017-05',
#        'freq_2017-04', 'freq_2017-03', 'freq_2017-02', 'freq_2017-01',
#        'freq_2016-12', 'freq_2016-11', 'freq_2016-10', 'freq_2016-09',
#        'freq_2016-08', 'freq_2016-07', 'freq_2016-06', 'freq_2016-05',
#        'freq_2016-04', 'freq_2016-03', 'freq_2016-02', 'freq_2016-01',
#        'coef_norm', 'coef_norm_max', 'coef'],
#       dtype='object')

# %%
# check the length of our df
len(df) #almost 75k unigrams
# Out:
# 74482

# %%
# print first five entries, to check last five just use 'tail'
df.head()
# Out:
#      freq_2018-08  freq_2018-07  freq_2018-06  freq_2018-05  freq_2018-04  \
# the     37.056363     37.081502     36.362193     36.265254     38.290656
# to      21.541353     21.100525     21.368631     21.052978     22.368968
# of      17.675905     17.466635     17.666530     17.468227     18.681636
# and     17.959034     17.475849     17.469527     17.140678     18.495243
# a       16.374574     15.939555     16.461464     15.990206     16.575330
#
#      freq_2018-03  freq_2018-02  freq_2018-01  freq_2017-12  freq_2017-11  \
# the     36.892588     35.648119     34.306137     37.113897     37.281825
# to      20.863747     20.426503     19.906267     21.348270     21.525584
# of      17.302120     17.171655     16.246601     17.818787     17.746266
# and     17.275354     16.631577     16.462514     17.730204     17.710685
# a       16.071832     15.764202     15.233668     16.398040     16.608227
#
#        ...     freq_2016-07  freq_2016-06  freq_2016-05  freq_2016-04  \
# the    ...        33.242451     30.139494     29.363555     32.108097
# to     ...        18.764140     17.005678     16.660130     18.601902
# of     ...        15.625277     14.150038     13.816681     14.858147
# and    ...        15.682630     14.243556     13.556952     14.955848
# a      ...        14.787194     13.476749     13.284766     14.614670
#
#      freq_2016-03  freq_2016-02  freq_2016-01  coef_norm  coef_norm_max  \
# the     31.166354     31.698902     30.066166   0.006185       0.005622
# to      17.813624     17.604342     16.705258   0.006992       0.006223
# of      14.459303     14.482511     14.078141   0.007307       0.006428
# and     14.396546     14.174071     13.847451   0.007216       0.006394
# a       13.758060     13.799080     13.101854   0.005730       0.005318
#
#          coef
# the  0.215275
# to   0.139192
# of   0.120088
# and  0.118261
# a    0.088325
#
# [5 rows x 35 columns]

# %% [markdown]
# #### We have not removed the stopwords
# #### Their frequency should not change over time, therefore we do not have to worry about them

# %%
df_sort=df.loc[df['coef_norm']>0.025].sort_values('coef', ascending=False) #let's sort by coef, and use coef_norm treshold to remove uninteresting words (stopwords!)

# %%
df_sort.head()
# Out:
#           freq_2018-08  freq_2018-07  freq_2018-06  freq_2018-05  \
# facebook      0.691789      0.938504      0.704737      0.799504
# ai            0.551516      0.444421      0.602350      0.507660
# 2018          0.391576      0.391525      0.373125      0.353062
# 2017          0.267850      0.260101      0.281343      0.256906
# machin        0.420034      0.334845      0.499722      0.430519
#
#           freq_2018-04  freq_2018-03  freq_2018-02  freq_2018-01  \
# facebook      1.551831      1.457819      0.480817      0.566736
# ai            0.544091      0.436456      0.460527      0.410719
# 2018          0.383118      0.424902      0.437326      0.530771
# 2017          0.289900      0.315720      0.333033      0.429080
# machin        0.650738      0.401076      0.339057      0.358827
#
#           freq_2017-12  freq_2017-11    ...     freq_2016-07  freq_2016-06  \
# facebook      0.640504      0.658798    ...         0.508581      0.429258
# ai            0.518325      0.642009    ...         0.176713      0.111236
# 2018          0.329986      0.161702    ...         0.023988      0.021660
# 2017          0.392506      0.281522    ...         0.051749      0.050395
# machin        0.449848      0.412598    ...         0.231271      0.228089
#
#           freq_2016-05  freq_2016-04  freq_2016-03  freq_2016-02  \
# facebook      0.516099      0.562654      0.349790      0.425736
# ai            0.109621      0.057965      0.120010      0.050916
# 2018          0.020859      0.022350      0.024140      0.023019
# 2017          0.047643      0.040063      0.031756      0.034979
# machin        0.195359      0.181667      0.227221      0.181607
#
#           freq_2016-01  coef_norm  coef_norm_max      coef
# facebook      0.389665   0.027305       0.010764  0.016704
# ai            0.082339   0.048121       0.025892  0.016623
# 2018          0.018493   0.100980       0.028012  0.014868
# 2017          0.040276   0.046555       0.024355  0.010450
# machin        0.188049   0.025725       0.013434  0.008742
#
# [5 rows x 35 columns]

# %% [markdown]
# #### most growing words are facebook and ai
# #### Let's prepare a simple visualisation

# %%
df_sort=df_sort.transpose()

# %%
df_sort
# Out:
#                facebook        ai      2018      2017    machin    amazon  \
# freq_2018-08   0.691789  0.551516  0.391576  0.267850  0.420034  0.375393
# freq_2018-07   0.938504  0.444421  0.391525  0.260101  0.334845  0.427819
# freq_2018-06   0.704737  0.602350  0.373125  0.281343  0.499722  0.371008
# freq_2018-05   0.799504  0.507660  0.353062  0.256906  0.430519  0.402594
# freq_2018-04   1.551831  0.544091  0.383118  0.289900  0.650738  0.552405
# freq_2018-03   1.457819  0.436456  0.424902  0.315720  0.401076  0.309785
# freq_2018-02   0.480817  0.460527  0.437326  0.333033  0.339057  0.333155
# freq_2018-01   0.566736  0.410719  0.530771  0.429080  0.358827  0.391315
# freq_2017-12   0.640504  0.518325  0.329986  0.392506  0.449848  0.404166
# freq_2017-11   0.658798  0.642009  0.161702  0.281522  0.412598  0.422259
# freq_2017-10   0.647531  0.570930  0.113988  0.308434  0.434252  0.409174
# freq_2017-09   0.584867  0.452127  0.082785  0.287878  0.312640  0.354725
# freq_2017-08   0.369875  0.334229  0.066926  0.301554  0.343496  0.336272
# freq_2017-07   0.471878  0.436649  0.065960  0.320879  0.332656  0.358656
# freq_2017-06   0.470879  0.409869  0.062024  0.274485  0.401366  0.415782
# freq_2017-05   0.736222  0.378455  0.048462  0.328673  0.384552  0.299460
# freq_2017-04   0.675048  0.321931  0.055790  0.310191  0.397357  0.224125
# freq_2017-03   0.411989  0.309306  0.044113  0.308329  0.300254  0.266802
# freq_2017-02   0.423068  0.356038  0.045799  0.297881  0.339189  0.255209
# freq_2017-01   0.470990  0.375486  0.040836  0.391195  0.337752  0.236730
# freq_2016-12   0.566287  0.362085  0.042617  0.278429  0.343046  0.349769
# freq_2016-11   0.671438  0.222683  0.041246  0.133163  0.289711  0.294997
# freq_2016-10   0.458102  0.387685  0.022980  0.100735  0.421515  0.232286
# freq_2016-09   0.513485  0.172423  0.023445  0.077787  0.290291  0.218407
# freq_2016-08   0.431046  0.137214  0.023056  0.058666  0.215555  0.171909
# freq_2016-07   0.508581  0.176713  0.023988  0.051749  0.231271  0.237201
# freq_2016-06   0.429258  0.111236  0.021660  0.050395  0.228089  0.180711
# freq_2016-05   0.516099  0.109621  0.020859  0.047643  0.195359  0.167776
# freq_2016-04   0.562654  0.057965  0.022350  0.040063  0.181667  0.207812
# freq_2016-03   0.349790  0.120010  0.024140  0.031756  0.227221  0.222789
# freq_2016-02   0.425736  0.050916  0.023019  0.034979  0.181607  0.218957
# freq_2016-01   0.389665  0.082339  0.018493  0.040276  0.188049  0.224047
# coef_norm      0.027305  0.048121  0.100980  0.046555  0.025725  0.026745
# coef_norm_max  0.010764  0.025892  0.028012  0.024355  0.013434  0.014938
# coef           0.016704  0.016623  0.014868  0.010450  0.008742  0.008252
#
#                      5g  cryptocurr   sponsor  cambridg      ...       \
# freq_2018-08   0.237334    0.061199  0.189330  0.042821      ...
# freq_2018-07   0.248674    0.078838  0.187104  0.094493      ...
# freq_2018-06   0.154382    0.102157  0.187459  0.061641      ...
# freq_2018-05   0.148557    0.097911  0.185012  0.172474      ...
# freq_2018-04   0.168131    0.104159  0.196356  0.348580      ...
# freq_2018-03   0.197383    0.136180  0.187539  0.511789      ...
# freq_2018-02   0.382688    0.256702  0.192476  0.019414      ...
# freq_2018-01   0.248985    0.298314  0.187278  0.009218      ...
# freq_2017-12   0.152826    0.247508  0.016969  0.008330      ...
# freq_2017-11   0.126756    0.111292  0.030593  0.040382      ...
# freq_2017-10   0.103463    0.071938  0.025692  0.022332      ...
# freq_2017-09   0.088627    0.064630  0.023651  0.016932      ...
# freq_2017-08   0.035682    0.032590  0.024504  0.024267      ...
# freq_2017-07   0.050328    0.043468  0.029404  0.012033      ...
# freq_2017-06   0.057500    0.013921  0.026939  0.012654      ...
# freq_2017-05   0.046768    0.024333  0.017923  0.060238      ...
# freq_2017-04   0.077064    0.009922  0.034854  0.018838      ...
# freq_2017-03   0.063372    0.006599  0.027065  0.028105      ...
# freq_2017-02   0.106147    0.005558  0.028147  0.030422      ...
# freq_2017-01   0.047738    0.005937  0.019279  0.010238      ...
# freq_2016-12   0.023986    0.006897  0.024304  0.021301      ...
# freq_2016-11   0.038845    0.007581  0.029017  0.011197      ...
# freq_2016-10   0.050586    0.002208  0.036963  0.014345      ...
# freq_2016-09   0.051193    0.002639  0.027471  0.015250      ...
# freq_2016-08   0.020624    0.011170  0.035302  0.009932      ...
# freq_2016-07   0.062714    0.004966  0.033528  0.023012      ...
# freq_2016-06   0.032947    0.006231  0.036024  0.004356      ...
# freq_2016-05   0.038771    0.008784  0.025157  0.009282      ...
# freq_2016-04   0.022523    0.009808  0.034567  0.023917      ...
# freq_2016-03   0.007170    0.003510  0.030872  0.014462      ...
# freq_2016-02   0.059761    0.006002  0.035873  0.011857      ...
# freq_2016-01   0.011601    0.005295  0.037567  0.015190      ...
# coef_norm      0.073033    0.095293  0.078615  0.091899      ...
# coef_norm_max  0.018864    0.018450  0.027578  0.009648      ...
# coef           0.007219    0.005504  0.005415  0.004938      ...
#
#                       yngve        oreppa     slyngstad   vehicleshar  \
# freq_2018-08   1.428571e-04  1.428571e-04  1.428571e-04  1.428571e-04
# freq_2018-07   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2018-06   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2018-05   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2018-04   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2018-03   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2018-02   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2018-01   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-12   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-11   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-10   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-09   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-08   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-07   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-06   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-05   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-04   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-03   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-02   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-01   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2016-12   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2016-11   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2016-10   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2016-09   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2016-08   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2016-07   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2016-06   1.488834e-04  1.488834e-04  1.488834e-04  1.488834e-04
# freq_2016-05   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2016-04   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2016-03   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2016-02   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2016-01   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# coef_norm      2.617560e-02  2.617560e-02  2.617560e-02  2.617560e-02
# coef_norm_max  1.602866e-03  1.602866e-03  1.602866e-03  1.602866e-03
# coef           2.386401e-07  2.386401e-07  2.386401e-07  2.386401e-07
#
#                   shieldlik        weider     uncategor      antipoli  \
# freq_2018-08   0.000000e+00  1.285347e-04  1.285347e-04  1.285347e-04
# freq_2018-07   1.394700e-04  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2018-06   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2018-05   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2018-04   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2018-03   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2018-02   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2018-01   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-12   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-11   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-10   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-09   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-08   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-07   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-06   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-05   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-04   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-03   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-02   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2017-01   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2016-12   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2016-11   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2016-10   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2016-09   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2016-08   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2016-07   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2016-06   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2016-05   0.000000e+00  1.203369e-04  1.203369e-04  0.000000e+00
# freq_2016-04   1.124859e-04  0.000000e+00  0.000000e+00  1.124859e-04
# freq_2016-03   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2016-02   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# freq_2016-01   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# coef_norm      2.869007e-02  2.867667e-02  2.867667e-02  2.853036e-02
# coef_norm_max  1.619666e-03  1.735137e-03  1.735137e-03  1.671826e-03
# coef           2.258948e-07  2.230253e-07  2.230253e-07  2.148877e-07
#
#                    drainpip      dulllook
# freq_2018-08   1.257862e-04  1.257862e-04
# freq_2018-07   0.000000e+00  0.000000e+00
# freq_2018-06   0.000000e+00  0.000000e+00
# freq_2018-05   0.000000e+00  0.000000e+00
# freq_2018-04   0.000000e+00  0.000000e+00
# freq_2018-03   0.000000e+00  0.000000e+00
# freq_2018-02   0.000000e+00  0.000000e+00
# freq_2018-01   0.000000e+00  0.000000e+00
# freq_2017-12   0.000000e+00  0.000000e+00
# freq_2017-11   0.000000e+00  0.000000e+00
# freq_2017-10   0.000000e+00  0.000000e+00
# freq_2017-09   0.000000e+00  0.000000e+00
# freq_2017-08   0.000000e+00  0.000000e+00
# freq_2017-07   0.000000e+00  0.000000e+00
# freq_2017-06   0.000000e+00  0.000000e+00
# freq_2017-05   0.000000e+00  0.000000e+00
# freq_2017-04   0.000000e+00  0.000000e+00
# freq_2017-03   0.000000e+00  0.000000e+00
# freq_2017-02   0.000000e+00  0.000000e+00
# freq_2017-01   0.000000e+00  0.000000e+00
# freq_2016-12   0.000000e+00  0.000000e+00
# freq_2016-11   0.000000e+00  0.000000e+00
# freq_2016-10   0.000000e+00  0.000000e+00
# freq_2016-09   0.000000e+00  0.000000e+00
# freq_2016-08   0.000000e+00  0.000000e+00
# freq_2016-07   0.000000e+00  0.000000e+00
# freq_2016-06   0.000000e+00  0.000000e+00
# freq_2016-05   0.000000e+00  0.000000e+00
# freq_2016-04   1.124859e-04  1.124859e-04
# freq_2016-03   0.000000e+00  0.000000e+00
# freq_2016-02   0.000000e+00  0.000000e+00
# freq_2016-01   0.000000e+00  0.000000e+00
# coef_norm      2.676214e-02  2.676214e-02
# coef_norm_max  1.584204e-03  1.584204e-03
# coef           1.992710e-07  1.992710e-07
#
# [35 rows x 41845 columns]

# %%
#Let's focus on the most trending words
df_sort=df_sort[['facebook', 'ai', 'machin', 'amazon', '5g', 'cryptocurr', 'cambridg']]

# %%
# erase last 3 rows

df_sort.drop(df_sort.tail(3).index,inplace=True)
# Out:
# /Users/kgyodi/miniconda3/envs/myPython/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# change the index for the visualisation
df_sort.reset_index(inplace=True)
df_sort['date']=df_sort['index'].str.replace('freq_', '')
df_sort['date']=pd.to_datetime(df_sort['date'])
# Out:
# /Users/kgyodi/miniconda3/envs/myPython/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/kgyodi/miniconda3/envs/myPython/lib/python3.5/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_sort=df_sort.drop('index', 1)
df_sort['date']=df_sort.index
df_sort=df_sort.set_index(df_sort['date'])

# %%
df_sort=df_sort.set_index(df_sort['date'])

# %%
df_sort=df_sort.drop('date', 1)

# %%
iplot(df_2.iplot(asFigure=True,
                               kind='scatter',xTitle='Months',yTitle='Frequency',title=''))
# Out:
# <div id="3c79e266-c7ac-4307-8f64-d492b16ecb28" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3c79e266-c7ac-4307-8f64-d492b16ecb28", [{"type": "scatter", "y": [0.6917888314832336, 0.9385042659721738, 0.7047371890309024, 0.7995036303425122, 1.5518314939115998, 1.4578190282324657, 0.4808165864398577, 0.5667361645273739, 0.6405043831611168, 0.6587980687095771, 0.647530832911906, 0.5848666864187533, 0.3698753890263852, 0.4718783088288541, 0.4708792717188631, 0.7362215528549004, 0.6750481908500395, 0.4119890438915365, 0.4230682424139062, 0.4709903356702882, 0.5662869699575945, 0.6714383523906847, 0.4581023780849621, 0.5134849666029517, 0.4310459684097905, 0.5085813210335244, 0.4292580380427348, 0.5160987789112365, 0.5626538396654429, 0.3497903714873014, 0.4257362847775331, 0.389664569961412], "mode": "lines", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1.3, "dash": "solid"}, "name": "facebook", "x": ["2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01", "2018-04-01", "2018-03-01", "2018-02-01", "2018-01-01", "2017-12-01", "2017-11-01", "2017-10-01", "2017-09-01", "2017-08-01", "2017-07-01", "2017-06-01", "2017-05-01", "2017-04-01", "2017-03-01", "2017-02-01", "2017-01-01", "2016-12-01", "2016-11-01", "2016-10-01", "2016-09-01", "2016-08-01", "2016-07-01", "2016-06-01", "2016-05-01", "2016-04-01", "2016-03-01", "2016-02-01", "2016-01-01"], "text": ""}, {"type": "scatter", "y": [0.5515157613044758, 0.4444212884715486, 0.6023497081108696, 0.5076602170663441, 0.5440913770666826, 0.4364555731447959, 0.4605271903583206, 0.4107190346705687, 0.5183254285722925, 0.6420085565578129, 0.5709302259428523, 0.452126642707586, 0.33422917044431744, 0.43664893356980455, 0.4098688754501554, 0.3784549273841822, 0.3219305184799718, 0.3093064008500136, 0.35603798450179763, 0.3754860352180181, 0.3620853901946561, 0.22268302579671573, 0.3876851330069416, 0.17242264637932228, 0.13721408279931882, 0.17671288415202324, 0.11123559515273268, 0.1096208486153916, 0.05796491853508705, 0.12001040668874592, 0.05091631206820505, 0.0823391259975655], "mode": "lines", "line": {"color": "rgba(55, 128, 191, 1.0)", "width": 1.3, "dash": "solid"}, "name": "ai", "x": ["2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01", "2018-04-01", "2018-03-01", "2018-02-01", "2018-01-01", "2017-12-01", "2017-11-01", "2017-10-01", "2017-09-01", "2017-08-01", "2017-07-01", "2017-06-01", "2017-05-01", "2017-04-01", "2017-03-01", "2017-02-01", "2017-01-01", "2016-12-01", "2016-11-01", "2016-10-01", "2016-09-01", "2016-08-01", "2016-07-01", "2016-06-01", "2016-05-01", "2016-04-01", "2016-03-01", "2016-02-01", "2016-01-01"], "text": ""}, {"type": "scatter", "y": [0.4200341972104755, 0.3348446418297281, 0.4997221109851847, 0.4305185665657064, 0.6507375431722231, 0.4010758445515312, 0.339057367997069, 0.3588272486820557, 0.4498483847820901, 0.4125978976544917, 0.4342524046525818, 0.312640409263828, 0.3434958241747013, 0.33265584085892985, 0.4013657476443614, 0.3845521289622185, 0.3973565505106498, 0.30025385020929163, 0.3391892483072043, 0.3377522840495565, 0.3430455701192985, 0.2897109997707167, 0.4215146189424221, 0.2902911754486401, 0.21555462459456007, 0.2312711075315957, 0.2280893682112461, 0.19535894286800395, 0.18166659846644204, 0.2272205909020965, 0.1816065048879225, 0.18804852774647965], "mode": "lines", "line": {"color": "rgba(50, 171, 96, 1.0)", "width": 1.3, "dash": "solid"}, "name": "machin", "x": ["2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01", "2018-04-01", "2018-03-01", "2018-02-01", "2018-01-01", "2017-12-01", "2017-11-01", "2017-10-01", "2017-09-01", "2017-08-01", "2017-07-01", "2017-06-01", "2017-05-01", "2017-04-01", "2017-03-01", "2017-02-01", "2017-01-01", "2016-12-01", "2016-11-01", "2016-10-01", "2016-09-01", "2016-08-01", "2016-07-01", "2016-06-01", "2016-05-0 ...

# %% [markdown]
# # Co-occurrence analysis

# %% [markdown]
# ## Let's explore the relationship between topics
#
# ### Pairs of terms which are mentioned together in media articles
# ### Most trending social issues have been selected
# ### The co-occurrence analysis is calculated for pairs consisting of emerging social issues and trending uni/bigrams
# ### The number of times the terms appear in articles together with a social issue is divided by the number of times the social issue is mentioned across all articles
# ### A single index is constructed for all word pairs by weighted average (with the same weights as in the case of frequencies)
# ### You can choose between all combinatios of co-occurring unigrams and bigrams (4)

# %%
# import dataframe- this one is for bigrams-bigrams
path='/Volumes/GoogleDrive/My Drive/NGI/Engineroom/analysis/181106_hackathon/res_0909/cooc22weighted.csv'
df=pd.read_csv(path, index_col=0)
#df.rename(columns={'Unnamed: 0':'word'},inplace=True)

# %%
#df['index']

# %%
##for convenience let's increase number of rows that can be printed

pd.options.display.max_colwidth = 1000
pd.set_option('display.max_rows',1000)

# %%
df.reset_index(inplace=True)

# %%
df=df.rename(columns={'index': 'word'})

# %%
df.columns
# Out:
# Index(['word', 'internet freedom_count_freq_weighted',
#        'internet freedom_count_freq_weighted_normalized',
#        'internet freedom_count_freq_weighted_normalized_root',
#        'internet freedom_bool_freq_weighted',
#        'internet freedom_bool_freq_weighted_normalized',
#        'internet freedom_bool_freq_weighted_normalized_root',
#        'russian interfer_count_freq_weighted',
#        'russian interfer_count_freq_weighted_normalized',
#        'russian interfer_count_freq_weighted_normalized_root',
#        ...
#        'network neutral_count_freq_weighted_normalized_root',
#        'network neutral_bool_freq_weighted',
#        'network neutral_bool_freq_weighted_normalized',
#        'network neutral_bool_freq_weighted_normalized_root',
#        'person data_count_freq_weighted',
#        'person data_count_freq_weighted_normalized',
#        'person data_count_freq_weighted_normalized_root',
#        'person data_bool_freq_weighted',
#        'person data_bool_freq_weighted_normalized',
#        'person data_bool_freq_weighted_normalized_root'],
#       dtype='object', length=103)

# %% [markdown]
# ### The columns are the selected social issues for which we calculated co-occurrences
# ### 3 different methods: count_freq_weighted / freq_weighted_normalized_root /  freq_weighted_normalized_root
#
# ### In our analysis, we have used count_freq_weighted

# %%
cols=[]
for i in df.columns:
    if 'count' in str(i):
        cols.append(i)
        print (i)
# Out:
# internet freedom_count_freq_weighted
# internet freedom_count_freq_weighted_normalized
# internet freedom_count_freq_weighted_normalized_root
# russian interfer_count_freq_weighted
# russian interfer_count_freq_weighted_normalized
# russian interfer_count_freq_weighted_normalized_root
# cambridg analytica_count_freq_weighted
# cambridg analytica_count_freq_weighted_normalized
# cambridg analytica_count_freq_weighted_normalized_root
# autonom weapon_count_freq_weighted
# autonom weapon_count_freq_weighted_normalized
# autonom weapon_count_freq_weighted_normalized_root
# hate speech_count_freq_weighted
# hate speech_count_freq_weighted_normalized
# hate speech_count_freq_weighted_normalized_root
# youtub kid_count_freq_weighted
# youtub kid_count_freq_weighted_normalized
# youtub kid_count_freq_weighted_normalized_root
# chines tech_count_freq_weighted
# chines tech_count_freq_weighted_normalized
# chines tech_count_freq_weighted_normalized_root
# distribut ledger_count_freq_weighted
# distribut ledger_count_freq_weighted_normalized
# distribut ledger_count_freq_weighted_normalized_root
# conspiraci theori_count_freq_weighted
# conspiraci theori_count_freq_weighted_normalized
# conspiraci theori_count_freq_weighted_normalized_root
# fake news_count_freq_weighted
# fake news_count_freq_weighted_normalized
# fake news_count_freq_weighted_normalized_root
# black box_count_freq_weighted
# black box_count_freq_weighted_normalized
# black box_count_freq_weighted_normalized_root
# ai startup_count_freq_weighted
# ai startup_count_freq_weighted_normalized
# ai startup_count_freq_weighted_normalized_root
# privaci polici_count_freq_weighted
# privaci polici_count_freq_weighted_normalized
# privaci polici_count_freq_weighted_normalized_root
# money launder_count_freq_weighted
# money launder_count_freq_weighted_normalized
# money launder_count_freq_weighted_normalized_root
# digit health_count_freq_weighted
# digit health_count_freq_weighted_normalized
# digit health_count_freq_weighted_normalized_root
# network neutral_count_freq_weighted
# network neutral_count_freq_weighted_normalized
# network neutral_count_freq_weighted_normalized_root
# person data_count_freq_weighted
# person data_count_freq_weighted_normalized
# person data_count_freq_weighted_normalized_root

# %%
for i in cols:
    df=df.sort_values(i, ascending=False)
    print(i)
    display(df[['word', i]][:30])
# Out:
# internet freedom_count_freq_weighted
#                     word  internet freedom_count_freq_weighted
# 9110         net neutral                            251.634109
# 7035    internet freedom                             99.000000
# 9175        neutral rule                             64.512457
# 9615       open internet                             47.040477
# 11369    restor internet                             42.842610
# 989             ajit pai                             42.356292
# 5190      feder communic                             29.486463
# 3060    communic commiss                             28.253905
# 5156        fcc chairman                             26.418846
# 5580       freedom order                             22.244609
# 2657       chairman ajit                             20.576464
# 7039      internet order                             17.208579
# 1712    attorney general                             14.487280
# 10794     public comment                             13.492008
# 6856       inform servic                             13.148061
# 5158      fcc commission                             13.103756
# 9887        paid priorit                             12.929596
# 9139     network neutral                             12.839275
# 9172     neutral protect                             11.273926
# 2659        chairman pai                             10.846930
# 5142           fast lane                             10.261916
# 13249  telecommun servic                              9.872968
# 10760         provid isp                              9.709917
# 7040    internet pioneer                              9.617380
# 3019         commiss fcc                              9.298452
# 5093        fake comment                              9.238001
# 5168            fcc vote                              8.155966
# 9882            pai plan                              8.133778
# 10466      presid donald                              7.939035
# 2996      comment system                              7.924808
# internet freedom_count_freq_weighted_normalized
#                      word  internet freedom_count_freq_weighted_normalized
# 11369     restor internet                                     39764.470248
# 7035     internet freedom                                     39703.393926
# 5580        freedom order                                     37540.001288
# 3765             dc court                                     19045.763662
# 9881            pai order                                     17463.375914
# 2995       comment server                                     15521.577909
# 9177         neutral vote                                     14521.784172
# 7040     internet pioneer                                     13417.543176
# 5093         fake comment                                     11211.926067
# 7640             kill net                                     10981.215923
# 4732           evan greer                                     10701.429849
# 5170         fccs comment                                     10156.205071
# 7038        internet open                                     10144.831152
# 9884        pai statement                                      9983.400855
# 11417          review act                                      9930.544924
# 10729         protect net                                      9712.815888
# 13053        susan collin                                      9542.270345
# 9435         obamaera net                                      9529.177944
# 5506           former fcc                                      9480.493648
# 3227   congression review                                      9443.132096
# 10699      pronet neutral                                      9347.443646
# 7039       internet order                                      9256.612876
# 622               act cra                                      9175.710624
# 2992        comment oppos                                      9044.695041
# 8618      million comment                                      8957.035221
# 5197         feder regist                                      8627.352591
# 14729         without net                                      8531.571416
# 13789           trump fcc                                      8489.359711
# 10534     prioriti access                                      8486.815063
# 7517         john kennedi                                      8362.914744
# internet freedom_count_freq_weighted_normalized_root
#                      word  \
# 7035     internet freedom
# 11369     restor internet
# 9110          net neutral
# 5580        freedom order
# 9175         neutral rule
# 9615        open internet
# 989              ajit pai
# 7039       internet order
# 5156         fcc chairman
# 7040     internet pioneer
# 3765             dc court
# 2657        chairman ajit
# 5093         fake comment
# 9139      network neutral
# 2659         chairman pai
# 6856        inform servic
# 5190       feder communic
# 3060     communic commiss
# 9172      neutral protect
# 5158       fcc commission
# 9887         paid priorit
# 9882             pai plan
# 9881            pai order
# 10729         protect net
# 11417          review act
# 5197         feder regist
# 13249   telecommun servic
# 3227   congression review
# 7640             kill net
# 5142            fast lane
#
#        internet freedom_count_freq_weighted_normalized_root
# 7035                                            1982.583163
# 11369                                           1305.225529
# 9110                                            1189.033634
# 5580                                             913.817619
# 9175                                             561.100466
# 9615                                             546.245384
# 989                                              488.702712
# 7039                                             399.115465
# 5156                                             378.183246
# 7040                                             359.223615
# 3765                                             350.515327
# 2657                                             325.154462
# 5093                                             321.831919
# 9139                                             300.243574
# 2659                                             293.480414
# 6856                                             289.414645
# 5190                                             284.126428
# 3060                                             277.258439
# 9172                                             271.770568
# 5158                                             263.957916
# 9887                                             261.573976
# 9882                                             259.122665
# 9881                                             257.915641
# 10729                                            256.627410
# 11417                                            256.423557
# 5197                                             256.306371
# 13249                                            255.464249
# 3227                                             250.051470
# 7640                                             248.072415
# 5142                                             241.200892
# russian interfer_count_freq_weighted
#                      word  russian interfer_count_freq_weighted
# 11638    russian interfer                             87.000000
# 2447   cambridg analytica                             62.822648
# 10475    presidenti elect                             59.002167
# 6976    intellig committe                             34.676020
# 7113        investig into                             34.561873
# 14086            us elect                             34.198987
# 5098            fake news                             32.929562
# 13784      trump campaign                             31.225312
# 14116       us presidenti                             29.797870
# 7043    internet research                             28.354902
# 11328      research agenc                             28.301313
# 141            2016 elect                             26.651778
# 1075        alleg russian                             25.996078
# 11635      russian govern                             24.963627
# 10305            polit ad                             21.008969
# 147       2016 presidenti                             19.782925
# 150               2016 us                             19.750220
# 9031         nation cyber                             15.608050
# 7086         into russian                             15.216784
# 8340      mark zuckerberg                             15.186199
# 11873         secur centr                             15.019814
# 5092         fake account                             15.008293
# 10472        presid trump                             14.836345
# 11969      senat intellig                             14.357013
# 12593     special counsel                             12.984727
# 11504      robert mueller                             12.843897
# 4148   disinform campaign                             12.839272
# 13781     trump administr                             12.434478
# 3909             deni ani                             11.355137
# 10466       presid donald                             11.236157
# russian interfer_count_freq_weighted_normalized
#                      word  russian interfer_count_freq_weighted_normalized
# 11638    russian interfer                                     34897.125150
# 1075        alleg russian                                     29328.226122
# 6721        includ attack                                     21021.655152
# 12554         sow discord                                     21007.698483
# 12692    spread disinform                                     20716.323831
# 591          account post                                     18009.325146
# 4473          elect meddl                                     16339.878774
# 6706    inauthent account                                     15132.924787
# 13772          troll armi                                     14258.575897
# 7086         into russian                                     14023.450435
# 11626       russian actor                                     13478.903938
# 13058     suspici account                                     12960.732016
# 695            ad purchas                                     12308.079920
# 5513         former trump                                     11964.609842
# 3754           david hogg                                     11817.649709
# 9595      onlin disinform                                     11258.370931
# 110               2 other                                     10768.115211
# 7043    internet research                                     10742.464438
# 4464       elect facebook                                     10658.749695
# 11644        russian news                                     10633.590319
# 4148   disinform campaign                                     10472.816350
# 10469        presid putin                                     10129.236368
# 2967       collus between                                     10063.004639
# 11328      research agenc                                      9569.610458
# 14567       what cambridg                                      9517.645210
# 5000     facebook general                                      9504.271639
# 11563      rod rosenstein                                      9278.184027
# 13792            trump jr                                      9135.843846
# 4576          energi grid                                      9109.449079
# 4172         divis social                                      9090.390065
# russian interfer_count_freq_weighted_normalized_root
#                      word  \
# 11638    russian interfer
# 1075        alleg russian
# 7043    internet research
# 11328      research agenc
# 10475    presidenti elect
# 12554         sow discord
# 12692    spread disinform
# 7086         into russian
# 6976    intellig committe
# 6721        includ attack
# 14086            us elect
# 4473          elect meddl
# 13784      trump campaign
# 4148   disinform campaign
# 141            2016 elect
# 14116       us presidenti
# 591          account post
# 10305            polit ad
# 2447   cambridg analytica
# 4464       elect facebook
# 147       2016 presidenti
# 11635      russian govern
# 11504      robert mueller
# 150               2016 us
# 12593     special counsel
# 13772          troll armi
# 11644        russian news
# 5092         fake account
# 13792            trump jr
# 695            ad purchas
#
#        russian interfer_count_freq_weighted_normalized_root
# 11638                                           1742.426437
# 1075                                             873.166002
# 7043                                             551.907171
# 11328                                            520.415743
# 10475                                            516.148404
# 12554                                            479.230117
# 12692                                            464.884890
# 7086                                             461.943520
# 6976                                             458.877458
# 6721                                             407.789598
# 14086                                            384.120162
# 4473                                             379.382858
# 13784                                            374.317341
# 4148                                             366.692429
# 141                                              360.201732
# 14116                                            356.579011
# 591                                              356.122961
# 10305                                            336.661885
# 2447                                             332.579517
# 4464                                             332.192126
# 147                                              330.127742
# 11635                                            327.013679
# 11504                                            323.870350
# 150                                              314.225626
# 12593                                            314.217795
# 13772                                            312.943929
# 11644                                            274.949550
# 5092                                             262.796904
# 13792                                            261.086609
# 695                                              260.223044
# cambridg analytica_count_freq_weighted
#                      word  cambridg analytica_count_freq_weighted
# 2447   cambridg analytica                              100.000000
# 8340      mark zuckerberg                               16.587448
# 5059        facebook user                               14.231464
# 14160           user data                               13.688794
# 5098            fake news                               13.282477
# 10123         person data                               12.835548
# 4983        facebook data                               12.466493
# 1331    analytica scandal                               11.057173
# 3723         data protect                                8.232792
# 10132       person inform                                8.164677
# 391            50 million                                7.391690
# 3902     democrat process                                7.035642
# 2634          ceo richard                                6.193548
# 14643         white paper                                6.190608
# 1839         back control                                6.118062
# 9898        paper publish                                6.049561
# 7300             it hadnt                                6.047639
# 7573          just affect                                6.037453
# 13218      technolog last                                6.000000
# 8624     million facebook                                5.853747
# 513            87 million                                5.229429
# 13784      trump campaign                                5.185124
# 6843    inform commission                                4.820016
# 10475    presidenti elect                                4.502805
# 5032      facebook profil                                4.284332
# 1317          analyt firm                                4.077025
# 10555         privaci set                                3.984006
# 3720         data privaci                                3.958569
# 10313       polit consult                                3.927470
# 5330        firm cambridg                                3.812184
# cambridg analytica_count_freq_weighted_normalized
#                         word  \
# 7573             just affect
# 13218         technolog last
# 4223            dorsey grill
# 2634             ceo richard
# 1839            back control
# 5028          facebook posit
# 3867     deletefacebook seem
# 9788           over cambridg
# 13655          traction mark
# 7300                it hadnt
# 14984       zuckerberg figur
# 292             270000 peopl
# 9873                page api
# 10415             power rule
# 2311            british data
# 1322          analytica data
# 14567          what cambridg
# 4975       facebook cambridg
# 1493              app review
# 1328       analytica harvest
# 1324           analytica did
# 5150                 fb isnt
# 8790           monopoli stat
# 2272         breach facebook
# 5330           firm cambridg
# 1329        analytica parent
# 1323        analytica debacl
# 3902        democrat process
# 11071           recent stori
# 1321   analytica controversi
#
#        cambridg analytica_count_freq_weighted_normalized
# 7573                                        17773.627036
# 13218                                        8660.855917
# 4223                                         7690.870155
# 2634                                         7408.269228
# 1839                                         5382.771504
# 5028                                         5142.820056
# 3867                                         5012.203811
# 9788                                         4832.299585
# 13655                                        4400.776510
# 7300                                         4256.905399
# 14984                                        4249.395895
# 292                                          4147.016556
# 9873                                         4116.574673
# 10415                                        4087.825508
# 2311                                         4020.306298
# 1322                                         3901.335063
# 14567                                        3877.955590
# 4975                                         3854.674597
# 1493                                         3841.833354
# 1328                                         3657.667794
# 1324                                         3655.748600
# 5150                                         3652.173146
# 8790                                         3652.173146
# 2272                                         3645.568460
# 5330                                         3466.340847
# 1329                                         3397.128707
# 1323                                         3347.377057
# 3902                                         3273.833325
# 11071                                        3245.196301
# 1321                                         3218.638178
# cambridg analytica_count_freq_weighted_normalized_root
#                       word  \
# 2447    cambridg analytica
# 7573           just affect
# 13218       technolog last
# 2634           ceo richard
# 1839          back control
# 1331     analytica scandal
# 7300              it hadnt
# 4983         facebook data
# 3902      democrat process
# 5059         facebook user
# 8624      million facebook
# 5330         firm cambridg
# 14160            user data
# 513             87 million
# 1322        analytica data
# 8340       mark zuckerberg
# 3483       crimson hexagon
# 10313        polit consult
# 11804            scl group
# 14643          white paper
# 4223          dorsey grill
# 3867   deletefacebook seem
# 1016           alexand nix
# 1493            app review
# 994        aleksandr kogan
# 5028        facebook posit
# 3264      consult cambridg
# 3695             data firm
# 391             50 million
# 5032       facebook profil
#
#        cambridg analytica_count_freq_weighted_normalized_root
# 2447                                               529.394303
# 7573                                               327.578145
# 13218                                              227.958627
# 2634                                               214.204281
# 1839                                               181.472125
# 1331                                               179.513672
# 7300                                               160.450072
# 4983                                               156.156638
# 3902                                               151.767975
# 5059                                               136.494499
# 8624                                               132.602911
# 5330                                               114.953592
# 14160                                              112.810310
# 513                                                110.813992
# 1322                                               105.609696
# 8340                                               102.893477
# 3483                                                99.338343
# 10313                                               88.148154
# 11804                                               87.811107
# 14643                                               85.727211
# 4223                                                84.859821
# 3867                                                84.459893
# 1016                                                83.316103
# 1493                                                80.889956
# 994                                                 79.644072
# 5028                                                78.393179
# 3264                                                74.559252
# 3695                                                72.869396
# 391                                                 72.622028
# 5032                                                72.477956
# autonom weapon_count_freq_weighted
#                     word  autonom weapon_count_freq_weighted
# 1802      autonom weapon                           94.000000
# 1643   artifici intellig                           62.166975
# 7645        killer robot                           39.895373
# 14494      weapon system                           32.367881
# 7938      lethal autonom                           26.437385
# 8166        machin learn                           26.280954
# 6521         human right                           22.442706
# 10684      project maven                           21.397595
# 4513           elon musk                           16.192246
# 958            ai system                           12.491525
# 3843       defens depart                           10.545724
# 5618          full stori                           10.196078
# 8444       meaning human                            9.363460
# 5942       googl employe                            7.949669
# 7968       life institut                            7.233719
# 3343      convent weapon                            7.128004
# 5071     facial recognit                            6.893659
# 11746       saudi arabia                            6.500000
# 13453       these weapon                            6.431630
# 961         ai technolog                            5.872835
# 2640     certain convent                            5.796670
# 944          ai research                            5.086320
# 966            ai weapon                            4.960784
# 3983          develop ai                            4.661064
# 6971         intellig ai                            4.506176
# 10562      privat corpor                            4.500000
# 13563         tobi walsh                            4.365807
# 12545         south wale                            3.940275
# 1605            arm forc                            3.900145
# 14014      univers robot                            3.827778
# autonom weapon_count_freq_weighted_normalized
#                          word  autonom weapon_count_freq_weighted_normalized
# 8444            meaning human                                   22585.113187
# 966                 ai weapon                                   22428.381128
# 2640          certain convent                                   19791.470844
# 7938           lethal autonom                                   15542.848362
# 7968            life institut                                   14726.425821
# 14493           weapon should                                   14313.650284
# 939               ai principl                                   14238.585358
# 1802           autonom weapon                                   13715.367687
# 10684           project maven                                   12981.070762
# 7645             killer robot                                   12864.092517
# 3785              death decis                                   12023.756935
# 13563              tobi walsh                                   11627.927368
# 5091             faith follow                                   11406.798746
# 14417       warfar crossfunct                                   11335.962840
# 1025         algorithm warfar                                   11005.898291
# 1335             analyz drone                                   10210.613568
# 4435            effect nation                                    9744.281798
# 894                  ai chief                                    9599.872681
# 7233                 it blind                                    9352.304390
# 13278          tensorflow api                                    9305.592357
# 4143   discriminatori practic                                    9268.732466
# 8711                   ml kit                                    9268.191850
# 13142          target without                                    9258.542692
# 3343           convent weapon                                    9033.959881
# 14494           weapon system                                    8911.060164
# 13212          technolog flag                                    8757.299720
# 11668        safeguard around                                    8539.371196
# 13618            topic intern                                    8111.165481
# 10955              rais valid                                    7561.739571
# 13453            these weapon                                    7460.202519
# autonom weapon_count_freq_weighted_normalized_root
#                          word  \
# 1802           autonom weapon
# 7645             killer robot
# 7938           lethal autonom
# 14494           weapon system
# 10684           project maven
# 8444            meaning human
# 2640          certain convent
# 966                 ai weapon
# 7968            life institut
# 3343           convent weapon
# 3843            defens depart
# 13563              tobi walsh
# 13453            these weapon
# 14493           weapon should
# 1643        artifici intellig
# 939               ai principl
# 3785              death decis
# 10562           privat corpor
# 13142          target without
# 4143   discriminatori practic
# 6521              human right
# 8413              max tegmark
# 894                  ai chief
# 1025         algorithm warfar
# 5942            googl employe
# 5091             faith follow
# 14417       warfar crossfunct
# 3983               develop ai
# 14014           univers robot
# 958                 ai system
#
#        autonom weapon_count_freq_weighted_normalized_root
# 1802                                          1135.449058
# 7645                                           716.392186
# 7938                                           641.024392
# 14494                                          537.058783
# 10684                                          527.032919
# 8444                                           459.863898
# 2640                                           338.710246
# 966                                            333.560131
# 7968                                           326.384479
# 3343                                           253.759938
# 3843                                           238.332602
# 13563                                          225.311526
# 13453                                          219.046263
# 14493                                          205.775663
# 1643                                           197.660275
# 939                                            195.504522
# 3785                                           183.885655
# 10562                                          178.800170
# 13142                                          178.662170
# 4143                                           177.316086
# 6521                                           169.614258
# 8413                                           155.617935
# 894                                            150.304015
# 1025                                           144.335003
# 5942                                           131.249419
# 5091                                           130.805956
# 14417                                          130.399173
# 3983                                           127.686395
# 14014                                          126.237071
# 958                                            122.888002
# hate speech_count_freq_weighted
#                        word  hate speech_count_freq_weighted
# 6180            hate speech                        93.000000
# 5098              fake news                        42.500461
# 2266           brand safeti                        18.547268
# 8340        mark zuckerberg                        11.540307
# 8166           machin learn                        10.269503
# 8470         media platform                        10.179505
# 2447     cambridg analytica                         9.978208
# 6605          illeg content                         9.857770
# 7355            it platform                         7.061417
# 3633          daili stormer                         6.787757
# 11672           safeti issu                         6.199826
# 10475      presidenti elect                         5.962156
# 9484         offens content                         5.903671
# 1643      artifici intellig                         5.752336
# 14648     white supremacist                         5.691501
# 4930      extremist content                         5.636162
# 999               alex jone                         5.567317
# 6521            human right                         5.454655
# 11225         remov content                         4.871817
# 14116         us presidenti                         4.666830
# 5116            fals inform                         4.654574
# 13284  terrorist propaganda                         4.564458
# 13283     terrorist content                         4.463233
# 5001         facebook googl                         4.219735
# 14305       violent content                         4.082891
# 150                 2016 us                         3.939611
# 5092           fake account                         3.897079
# 3202           concern over                         3.781524
# 1322         analytica data                         3.757080
# 3194          comput vision                         3.518684
# hate speech_count_freq_weighted_normalized
#                        word  hate speech_count_freq_weighted_normalized
# 2266           brand safeti                                20639.490718
# 7611             keith weed                                11670.723377
# 4171            divis polit                                 9682.377704
# 3299         content appear                                 8100.485008
# 7556                june 19                                 8061.019271
# 6180            hate speech                                 7618.127974
# 6020        graphic violenc                                 7037.954910
# 14305       violent content                                 6550.280389
# 6865           infowar page                                 5870.682427
# 837            against hate                                 5692.374877
# 11229            remov hate                                 5626.372822
# 1322         analytica data                                 5127.070888
# 14062         urgent action                                 5044.218338
# 9484         offens content                                 5013.288510
# 8645               min aung                                 4935.975741
# 9163             netzdg law                                 4915.205878
# 1737               aung hla                                 4753.882168
# 211           2018 facebook                                 4647.432414
# 4117    direct relationship                                 4586.135609
# 3306         content review                                 4480.258010
# 7530           jone channel                                 4315.290866
# 11365        respond report                                 4254.759119
# 13284  terrorist propaganda                                 4244.716835
# 6181           hatr against                                 4173.880137
# 14315       virtual empathi                                 4114.285714
# 4929         extrem suscept                                 4092.491385
# 2634            ceo richard                                 3909.936574
# 12696           spread hate                                 3722.411596
# 1873               ban alex                                 3685.616068
# 11569       rohingya muslim                                 3608.912214
# hate speech_count_freq_weighted_normalized_root
#                        word  hate speech_count_freq_weighted_normalized_root
# 6180            hate speech                                       841.716046
# 2266           brand safeti                                       618.713320
# 5098              fake news                                       229.648586
# 7611             keith weed                                       196.311431
# 6605          illeg content                                       185.943802
# 9484         offens content                                       172.037229
# 4171            divis polit                                       171.701082
# 3299         content appear                                       164.722678
# 14305       violent content                                       163.536176
# 7556                june 19                                       155.509028
# 6020        graphic violenc                                       155.066860
# 11672           safeti issu                                       142.576340
# 11229            remov hate                                       140.501877
# 13284  terrorist propaganda                                       139.193508
# 1322         analytica data                                       138.790539
# 3633          daili stormer                                       124.077337
# 14062         urgent action                                       123.930716
# 837            against hate                                       120.224736
# 11225         remov content                                       119.738812
# 999               alex jone                                       119.094934
# 4117    direct relationship                                       118.169519
# 13283     terrorist content                                       117.495667
# 11365        respond report                                       113.820243
# 2634            ceo richard                                       113.052742
# 8470         media platform                                       103.839709
# 4930      extremist content                                       101.751985
# 11231           remov illeg                                        94.759214
# 5116            fals inform                                        91.741111
# 5036         facebook remov                                        87.100373
# 14648     white supremacist                                        85.939552
# youtub kid_count_freq_weighted
#                    word  youtub kid_count_freq_weighted
# 14950        youtub kid                       87.000000
# 6056        green paper                       41.250000
# 7633            kid app                       38.084195
# 3754         david hogg                       24.750000
# 14951      youtub music                       20.000000
# 9905     parent control                       19.385400
# 5098          fake news                       19.193878
# 3484        crisi actor                       16.794118
# 6116        gun control                       16.500000
# 14953    youtub premium                       15.846154
# 8470     media platform                       15.019231
# 8461         media firm                       14.250000
# 8071         logan paul                       14.020408
# 6253        help parent                       12.211931
# 8052      local languag                       12.000000
# 13968          under 13                       10.771909
# 2738     children under                       10.445378
# 12517         someth im                       10.000000
# 12204         sign into                       10.000000
# 3892          demand it                       10.000000
# 14289        video what                       10.000000
# 13621     total control                       10.000000
# 6891        initi setup                       10.000000
# 4738          even give                       10.000000
# 7164         ipod touch                       10.000000
# 1193          also view                       10.000000
# 3565      current locat                       10.000000
# 10475  presidenti elect                        9.933673
# 14945        youtub app                        9.919706
# 2725         child abus                        9.260204
# youtub kid_count_freq_weighted_normalized
#                    word  youtub kid_count_freq_weighted_normalized
# 3754         david hogg                              112267.672235
# 14950        youtub kid                               76947.240112
# 6056        green paper                               73337.378827
# 7633            kid app                               64478.591777
# 14953    youtub premium                               40073.088438
# 10723    protect expert                               36333.861502
# 5179       featur engin                               35588.919970
# 9307         news video                               28966.406852
# 3484        crisi actor                               28928.937904
# 9912   parkland florida                               25868.981926
# 14276       video claim                               25797.840258
# 8052      local languag                               25010.047456
# 4230        dougla high                               24282.753360
# 7448         jame bridl                               23950.215709
# 5977   googleown youtub                               23589.170085
# 8335   marjori stoneman                               23013.121780
# 14943    youtub alreadi                               22016.367844
# 12852   stoneman dougla                               20648.018490
# 14955      youtub remov                               20246.576309
# 4544         emot wellb                               19230.500808
# 5803     genuin concern                               18928.847847
# 837        against hate                               18494.954718
# 6891        initi setup                               18216.591593
# 14289        video what                               18161.991364
# 14277     video contain                               17868.903595
# 6331         hill calif                               17830.292199
# 6253        help parent                               17432.607221
# 11064  recent highlight                               17426.498435
# 5125   famili entertain                               17339.818464
# 1193          also view                               16248.834809
# youtub kid_count_freq_weighted_normalized_root
#                    word  youtub kid_count_freq_weighted_normalized_root
# 14950        youtub kid                                     2587.355772
# 6056        green paper                                     1739.300686
# 3754         david hogg                                     1666.920780
# 7633            kid app                                     1567.040292
# 14953    youtub premium                                      796.871586
# 3484        crisi actor                                      697.019359
# 8052      local languag                                      547.832611
# 10723    protect expert                                      547.498272
# 5179       featur engin                                      541.856614
# 14951      youtub music                                      533.567036
# 9307         news video                                      488.848501
# 9905     parent control                                      471.077928
# 9912   parkland florida                                      461.973052
# 6253        help parent                                      461.395487
# 14276       video claim                                      461.337384
# 5977   googleown youtub                                      450.059935
# 4230        dougla high                                      447.585428
# 8071         logan paul                                      446.422255
# 8335   marjori stoneman                                      435.727271
# 14943    youtub alreadi                                      427.674186
# 6891        initi setup                                      426.808992
# 14289        video what                                      426.168879
# 12852   stoneman dougla                                      412.730121
# 14277     video contain                                      405.842548
# 1193          also view                                      403.098435
# 14955      youtub remov                                      398.224701
# 5803     genuin concern                                      395.174638
# 6116        gun control                                      394.264096
# 837        against hate                                      390.619222
# 13968          under 13                                      389.579500
# chines tech_count_freq_weighted
#                              word  chines tech_count_freq_weighted
# 2783                  chines tech                        87.000000
# 13171                  tech giant                        37.581485
# 2769                chines govern                        16.027284
# 1643            artifici intellig                        13.170775
# 5504               former employe                        13.064516
# 2765               chines compani                        10.692897
# 2085                 billion yuan                        10.033236
# 436                    5g network                         9.454545
# 5414                      fli car                         9.340909
# 4656                    epic game                         8.613636
# 8166                 machin learn                         7.700880
# 6521                  human right                         7.556894
# 2748                  china mobil                         7.537646
# 3071              communist parti                         6.508844
# 5823                giant tencent                         6.219578
# 3139              comparison site                         6.215438
# 3140            comparison websit                         6.215438
# 9421                 nvidia drive                         6.101010
# 10262  playerunknown battleground                         6.074675
# 14890                     xi jinp                         5.343318
# 6976            intellig committe                         5.321312
# 7491                       job ad                         5.307604
# 13327                 test vehicl                         5.000000
# 2143             blackberri mobil                         4.950000
# 10624            processor vulner                         4.950000
# 9704                 other chines                         4.823358
# 944                   ai research                         4.327256
# 14136                    us trade                         4.204040
# 13675                   trade war                         4.011730
# 7839                 learn capabl                         4.000000
# chines tech_count_freq_weighted_normalized
#                     word  chines tech_count_freq_weighted_normalized
# 2783         chines tech                                55237.589260
# 10624   processor vulner                                23533.532829
# 12378   smartphon seller                                18571.518495
# 823            after zte                                17754.049215
# 3140   comparison websit                                14028.996565
# 9421        nvidia drive                                13991.835043
# 2143    blackberri mobil                                11231.322286
# 5823       giant tencent                                10401.981339
# 8778        money market                                 9969.894012
# 426            5g huawei                                 9892.141456
# 2750           china new                                 8978.969972
# 2741    china censorship                                 8801.053392
# 13273      tencent music                                 8703.427741
# 3136         compani zte                                 8129.828577
# 14919          year snap                                 8043.347114
# 12623        spectr flaw                                 8037.283818
# 14073           us cfius                                 8005.829207
# 5406         flash motor                                 7625.879358
# 2351      build artifici                                 7582.515015
# 7491              job ad                                 7500.485429
# 12405      social credit                                 7494.583485
# 9704        other chines                                 6973.525340
# 6456    huawei australia                                 6807.842138
# 3139     comparison site                                 6474.261947
# 13271       tencent buri                                 6317.886303
# 13554        tip hatchet                                 6317.886303
# 9202       new broadcast                                 5955.897483
# 2062    bikeshar compani                                 5868.699870
# 3360   coordin disclosur                                 5868.315449
# 14280        video frame                                 5746.148726
# chines tech_count_freq_weighted_normalized_root
#                     word  chines tech_count_freq_weighted_normalized_root
# 2783         chines tech                                      2192.183903
# 10624   processor vulner                                       341.307761
# 3140   comparison websit                                       295.290290
# 9421        nvidia drive                                       292.171742
# 12378   smartphon seller                                       263.130107
# 5823       giant tencent                                       254.353960
# 13171         tech giant                                       253.762245
# 2143    blackberri mobil                                       235.786016
# 823            after zte                                       201.374571
# 3139     comparison site                                       200.600031
# 7491              job ad                                       199.523443
# 2769       chines govern                                       191.425153
# 2750           china new                                       184.279410
# 9704        other chines                                       183.400680
# ...
# 8183           maco mojav                                  6145.181777
# 224           2018 keynot                                  6137.396862
# 71               15 octob                                  6136.954572
# 7136                io 12                                  6118.290854
# 6203        health minist                                  6006.847261
# 42                12 beta                                  5762.478037
# digit health_count_freq_weighted_normalized_root
#                      word  digit health_count_freq_weighted_normalized_root
# 4082         digit health                                       1506.150859
# 8969            my health                                        680.830419
# 6206        health record                                        653.948654
# 11337      research ethic                                        543.008083
# 7136                io 12                                        312.328465
# 3656            dark mode                                        279.806642
# 6192         health agenc                                        270.137989
# 1752     australian digit                                        247.246804
# 11101       record system                                        244.804805
# 5177       fda commission                                        236.453262
# 6077        group facetim                                        229.837317
# 5779   general practition                                        206.272480
# 6059            greg hunt                                        167.667573
# 8673          minist greg                                        165.610640
# 1756     australian medic                                        162.570037
# 3035     commission scott                                        158.550832
# 8181             maco app                                        158.335538
# 6513       human particip                                        150.782336
# 6203        health minist                                        148.197622
# 14864           wwdc 2018                                        143.701983
# 8183           maco mojav                                        141.902884
# 11807      scott gottlieb                                        137.290608
# 6530      human technolog                                        132.856812
# 6211     healthcar system                                        130.677022
# 14545          well spent                                        128.925437
# 4844          expand ptfe                                        128.359357
# 4498      electron health                                        118.241795
# 9320            nhs digit                                        114.901747
# 11096       record optout                                        111.896835
# 10828       public revenu                                        111.243903
# network neutral_count_freq_weighted
#                     word  network neutral_count_freq_weighted
# 9110         net neutral                           155.428953
# 9139     network neutral                            87.000000
# 9175        neutral rule                            51.769966
# 9615       open internet                            44.005255
# 7040    internet pioneer                            37.452381
# 14673        wilbur ross                            33.000000
# 989             ajit pai                            31.507912
# 5156        fcc chairman                            24.962159
# 7035    internet freedom                            21.523990
# 13781    trump administr                            20.230184
# 9172     neutral protect                            17.444395
# 7113       investig into                            16.843260
# 5190      feder communic                            16.652837
# 3060    communic commiss                            16.652837
# 14812       would elimin                            16.636364
# 4513           elon musk                            16.603448
# 7476           jeff bezo                            16.603448
# 12147    sheryl sandberg                            16.603448
# 3002   commerc secretari                            16.500000
# 9538               oh it                            16.500000
# 13806      trump twitter                            16.500000
# 5544        founder elon                            16.500000
# 1317         analyt firm                            16.500000
# 13046      surveil state                            16.500000
# 13859        twitter ceo                            16.500000
# 7053         into amazon                            16.500000
# 11862   secretari wilbur                            16.500000
# 13792           trump jr                            16.500000
# 4398      econom analysi                            15.772727
# 5155           fcc chair                            15.739812
# network neutral_count_freq_weighted_normalized
#                     word  network neutral_count_freq_weighted_normalized
# 14673        wilbur ross                                    65417.189928
# 9815      oversight hear                                    61445.049371
# 7040    internet pioneer                                    52251.128794
# 9139     network neutral                                    47575.758901
# 11862   secretari wilbur                                    45311.077535
# 3002   commerc secretari                                    32438.852603
# 4398      econom analysi                                    28092.872814
# 7053         into amazon                                    24231.984023
# 5580       freedom order                                    23505.856865
# 14812       would elimin                                    23267.945834
# 13806      trump twitter                                    22076.345067
# 13792           trump jr                                    20202.824212
# 9176     neutral support                                    20170.401765
# 2156           block att                                    17788.709948
# 9538               oh it                                    17544.033912
# 7799         law content                                    17500.219764
# 13046      surveil state                                    17295.570688
# 13073           swing it                                    16347.250212
# 11293        report what                                    15016.053524
# 13736      transpar rule                                    14714.702756
# 5155           fcc chair                                    14554.758782
# 11369    restor internet                                    14408.281466
# 5023       facebook oper                                    14000.034171
# 5544        founder elon                                    13063.653098
# 13509        throttl law                                    12922.750977
# 9590        onli serious                                    12371.270585
# 5160             fcc did                                    12279.781966
# 8863     mozilla foundat                                    12191.838083
# 9414         number show                                    11566.208016
# 10729        protect net                                    11431.820408
# network neutral_count_freq_weighted_normalized_root
#                     word  network neutral_count_freq_weighted_normalized_root
# 9139     network neutral                                          2034.475614
# 14673        wilbur ross                                          1469.274402
# 7040    internet pioneer                                          1398.902849
# 11862   secretari wilbur                                           864.657608
# 9815      oversight hear                                           789.195390
# 9110         net neutral                                           734.440390
# 3002   commerc secretari                                           731.601714
# 4398      econom analysi                                           665.658487
# 7053         into amazon                                           632.319331
# 14812       would elimin                                           622.168794
# 13806      trump twitter                                           603.539306
# 13792           trump jr                                           577.361758
# 5580       freedom order                                           572.191407
# 9538               oh it                                           538.030259
# 13046      surveil state                                           534.206810
# 9615       open internet                                           510.999657
# 5155           fcc chair                                           478.632600
# 11369    restor internet                                           472.936183
# 5544        founder elon                                           464.273924
# 9175        neutral rule                                           450.271978
# 9176     neutral support                                           449.114704
# 7035    internet freedom                                           431.041407
# 13859        twitter ceo                                           423.337339
# 9172     neutral protect                                           420.516601
# 11293        report what                                           387.505529
# 989             ajit pai                                           363.535171
# 5156        fcc chairman                                           357.330911
# 13748          treat all                                           352.291168
# 9414         number show                                           340.091282
# 5142           fast lane                                           335.989900
# person data_count_freq_weighted
#                      word  person data_count_freq_weighted
# 10123         person data                       100.000000
# 3723         data protect                        43.005749
# 2447   cambridg analytica                        35.776445
# 10132       person inform                        22.913283
# 3673          data breach                        22.634949
# 14160           user data                        12.803968
# 8166         machin learn                        12.631890
# 1643    artifici intellig                        12.107208
# 10737       protect regul                         9.869497
# 5771         general data                         9.303385
# 6843    inform commission                         9.210630
# 3720         data privaci                         8.703738
# 8340      mark zuckerberg                         7.500860
# 5059        facebook user                         7.426931
# 10548      privaci polici                         7.014243
# 10727         protect law                         5.532034
# 11151          regul gdpr                         5.524133
# 4983        facebook data                         5.509095
# 3034     commission offic                         5.268810
# 5098            fake news                         5.221287
# 3736           data share                         5.045733
# 11885        secur number                         4.652434
# 6521          human right                         4.630059
# 5946           googl home                         4.407030
# 7062          into effect                         4.374549
# 10544         privaci law                         4.316658
# 7113        investig into                         4.224028
# 10719         protect act                         3.999112
# 3270          consum data                         3.844731
# 14570           what data                         3.804349
# person data_count_freq_weighted_normalized
#                    word  person data_count_freq_weighted_normalized
# 14355        voic sampl                                 6193.506404
# 3468      credit bureau                                 5477.311908
# 4663     equifax breach                                 4275.617160
# 6248           help kid                                 3888.894504
# 10123       person data                                 3091.567029
# 5025   facebook permiss                                 2966.694431
# 2443          call voic                                 2934.072308
# 1133        also compli                                 2843.750166
# 3785        death decis                                 2798.494677
# 11548        robot voic                                 2620.863543
# 5740         gdpr appli                                 2514.688348
# 5743     gdpr compliant                                 2514.654490
# 2958     colleagu studi                                 2511.962753
# 67         1455 million                                 2511.753112
# 3731          data room                                 2508.827746
# 10598       process ani                                 2441.286464
# 10607    process person                                 2426.021908
# 14349         voic data                                 2374.923048
# 13972        under gdpr                                 2344.609025
# 534      aadhaar number                                 2322.581202
# 3663          data abus                                 2296.564805
# 5750          gdpr rule                                 2276.924729
# 3697          data gdpr                                 2264.254625
# 8419        mayb someon                                 2097.746834
# 8117          loss last                                 2085.462482
# 5748         gdpr regul                                 2046.813077
# 5742     gdpr complianc                                 2040.773178
# 3612       cyber intrus                                 2033.410780
# 11367     respons robot                                 2024.403939
# 14618         whi robot                                 2009.549425
# person data_count_freq_weighted_normalized_root
#                      word  person data_count_freq_weighted_normalized_root
# 10123         person data                                       556.018617
# 3723         data protect                                       215.644722
# 2447   cambridg analytica                                       189.398463
# 3673          data breach                                       146.535605
# 10132       person inform                                       145.670939
# 6248             help kid                                       113.264384
# 10737       protect regul                                       110.668910
# 4663       equifax breach                                       109.623794
# 5771         general data                                       106.772414
# 3720         data privaci                                       105.627536
# 14160           user data                                       105.518396
# 14355          voic sampl                                       105.344909
# 6843    inform commission                                        96.899219
# 11151          regul gdpr                                        91.571017
# 3468        credit bureau                                        85.578606
# 10548      privaci polici                                        84.410392
# 10727         protect law                                        77.650540
# 3034     commission offic                                        72.225411
# 11885        secur number                                        72.160027
# 5059        facebook user                                        71.231970
# 3736           data share                                        70.070229
# 13972          under gdpr                                        69.213780
# 4983        facebook data                                        69.007515
# 10719         protect act                                        68.897542
# 3680         data control                                        68.894929
# 10544         privaci law                                        68.798694
# 3270          consum data                                        65.486478
# 4085          digit ident                                        64.737944
# 2963       collect person                                        62.184772
# 5742       gdpr complianc                                        61.906290
